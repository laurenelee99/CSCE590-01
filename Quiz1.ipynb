# %%
import pandas
import matplotlib.pyplot as plt
import seaborn as sns

data = pandas.read_csv("WaterAtlas-OneLake.csv")
print(data)
#print(data.describe())
# Out:
#       WBodyID         WaterBodyName      DataSource      StationID  \
# 0     2003889  Okaloacoochee Branch    WIN_21FLSFWM          32275
# 1     2003889  Okaloacoochee Branch    WIN_21FLSFWM          32275
# 2     2003889  Okaloacoochee Branch    WIN_21FLSFWM          32275
# 3     2003889  Okaloacoochee Branch    WIN_21FLSFWM          32275
# 4     2003889  Okaloacoochee Branch    WIN_21FLSFWM          32275
# ...       ...                   ...             ...            ...
# 2284  2003889  Okaloacoochee Branch  STORET_21FLFTM  CALUSA0052FTM
# 2285  2003889  Okaloacoochee Branch  STORET_21FLFTM  CALUSA0052FTM
# 2286  2003889  Okaloacoochee Branch  STORET_21FLFTM  CALUSA0052FTM
# 2287  2003889  Okaloacoochee Branch  STORET_21FLFTM  CALUSA0052FTM
# 2288  2003889  Okaloacoochee Branch  STORET_21FLFTM  CALUSA0052FTM
#
#                          StationName Actual_StationID  Actual_Latitude  \
# 0                             CRFW09            32275         26.76290
# ...

# %%
#data['WBodyID'].fillna(int(data['WBodyID'].mean()), inplace = True) 
#data['WaterBodyName']
#data['DataSource']
#data['StationID']
#data['StationName']
#data['Actual_StationID']
#data['Actual_Latitude']
#data['Actual_Longitude']
#data['DEP_WBID']
#data['SampleDate']
#data['ActivityDepth']
#data['DepthUnits']
#data['Parameter']
#data['Characteristic']
#data = pandas.read_cvs("WaterAtlas-OneLake.csv", na_values = "")
#print(data)
#data['Sample_Fraction'].
#data['Result_Value']
#data['QACode']
#data['Result_Comment']
#data['Original_Result_Value']
#data['Original_Result_Unit']

# %%
#data["TN_ugl"].value_counts()
#data["NH3_N_ugl"].value_counts()
#data["NOx_ugl"].value_counts()
#data["TP_ugl"].value_counts()
#data["OP_mgl"].value_counts()
#data["DO_mgl"].value_counts()
#data["pH"].value_counts()
#data["Cond_umhocm"].value_counts()
#data["TempW_C"].value_counts()
#data["TempW_F"].value_counts()
data["ActivityDepth"].mean()
print()
print(data['Parameter'].value_counts())
print()
print(data['Characteristic'].value_counts())
print()
print(data['Sample_Fraction'].value_counts())
print()
data["Result_Value"].mean()
print()
print(data['Result_Unit'].value_counts())
print()
# Out:
# TP_ugl           126
# DO_mgl           107
# Cond_umhocm      107
# TempW_C          105
# TempW_F          105
#                 ...
# Endothall_ugl      5
# Diuron_ugl         5
# 24D_ugl            5
# Mn_ugl             1
# BOD5_mgl           1
# Name: Parameter, Length: 72, dtype: int64
#
# Temperature, water                210
# Phosphorus as P                   126
# Specific conductance              107
# Dissolved oxygen (DO)             107
# pH                                105
#                                  ...
# Endothall                           5
# Sucralose                           5
# Diuron                              5
# Mecoprop (MCPP)                     5
# BOD, Biochemical oxygen demand      1
# Name: Characteristic, Length: 61, dtype: int64
#
# Total              1266
# Dissolved           432
# Total Recovrble      37
# Name: Sample_Fraction, dtype: int64
#
#
# ug/l           933
# mg/l           690
# umho           107
# deg F          105
# ...

# %%
print("Parameters from 5/18/2020 11:11:00 AM")
data.loc[data['SampleDate'] == "5/18/2020 11:11:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 5/18/2020 11:11:00 AM
#      Parameter                                Characteristic Sample_Fraction  \
# 0       TN_ugl                                      Nitrogen           Total
# 1    NH3_N_ugl                        Nitrogen, ammonia as N       Dissolved
# 2      NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N       Dissolved
# 3       TP_ugl                               Phosphorus as P           Total
# 4       OP_mgl              Phosphorus, phosphate (PO4) as P       Dissolved
# 5       DO_mgl                         Dissolved oxygen (DO)             NaN
# 6           pH                                            pH             NaN
# 7  Cond_umhocm                          Specific conductance             NaN
# 8      TempW_C                            Temperature, water             NaN
# 9      TempW_F                            Temperature, water             NaN
#
#    Result_Value Result_Unit
# 0      1280.000        ug/l
# ...

# %%
print("Parameters from 06-01-2020 11:29")
data.loc[data['SampleDate'] == "06-01-2020 11:29", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 06-01-2020 11:29
#       Parameter                                Characteristic Sample_Fraction  \
# 10       TN_ugl                                      Nitrogen           Total
# 11    NH3_N_ugl                        Nitrogen, ammonia as N       Dissolved
# 12      NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N       Dissolved
# 13       TP_ugl                               Phosphorus as P           Total
# 14       OP_mgl              Phosphorus, phosphate (PO4) as P       Dissolved
# 15       DO_mgl                         Dissolved oxygen (DO)             NaN
# 16           pH                                            pH             NaN
# 17  Cond_umhocm                          Specific conductance             NaN
# 18      TempW_C                            Temperature, water             NaN
# 19      TempW_F                            Temperature, water             NaN
#
#     Result_Value Result_Unit
# 10      1220.000        ug/l
# ...

# %%
print("Parameters from 6/15/2020 11:30:00 AM")
data.loc[data['SampleDate'] == "6/15/2020 11:30:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 6/15/2020 11:30:00 AM
#       Parameter                                Characteristic Sample_Fraction  \
# 20       TN_ugl                                      Nitrogen           Total
# 21    NH3_N_ugl                        Nitrogen, ammonia as N       Dissolved
# 22      NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N       Dissolved
# 23       TP_ugl                               Phosphorus as P           Total
# 24       OP_mgl              Phosphorus, phosphate (PO4) as P       Dissolved
# 25       DO_mgl                         Dissolved oxygen (DO)             NaN
# 26           pH                                            pH             NaN
# 27  Cond_umhocm                          Specific conductance             NaN
# 28      TempW_C                            Temperature, water             NaN
# 29      TempW_F                            Temperature, water             NaN
#
#     Result_Value Result_Unit
# 20      1130.000        ug/l
# ...

# %%
print("Parameters from 6/29/2020 11:07:00 AM")
data.loc[data['SampleDate'] == "6/29/2020 11:07:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 6/29/2020 11:07:00 AM
#       Parameter                                Characteristic Sample_Fraction  \
# 30       TN_ugl                                      Nitrogen           Total
# 31    NH3_N_ugl                        Nitrogen, ammonia as N       Dissolved
# 32      NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N       Dissolved
# 33       TP_ugl                               Phosphorus as P           Total
# 34       OP_mgl              Phosphorus, phosphate (PO4) as P       Dissolved
# 35       DO_mgl                         Dissolved oxygen (DO)             NaN
# 36           pH                                            pH             NaN
# 37  Cond_umhocm                          Specific conductance             NaN
# 38      TempW_C                            Temperature, water             NaN
# 39      TempW_F                            Temperature, water             NaN
#
#     Result_Value Result_Unit
# 30      1090.000        ug/l
# ...

# %%
print("Parameters from 7/13/2020 11:32:00 AM")
data.loc[data['SampleDate'] == "7/13/2020 11:32:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 7/13/2020 11:32:00 AM
#       Parameter                                Characteristic Sample_Fraction  \
# 40       TN_ugl                                      Nitrogen           Total
# 41    NH3_N_ugl                        Nitrogen, ammonia as N       Dissolved
# 42      NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N       Dissolved
# 43       TP_ugl                               Phosphorus as P           Total
# 44       OP_mgl              Phosphorus, phosphate (PO4) as P       Dissolved
# 45       DO_mgl                         Dissolved oxygen (DO)             NaN
# 46           pH                                            pH             NaN
# 47  Cond_umhocm                          Specific conductance             NaN
# 48      TempW_C                            Temperature, water             NaN
# 49      TempW_F                            Temperature, water             NaN
#
#     Result_Value Result_Unit
# 40      1240.000        ug/l
# ...

# %%
print("Parameters from 7/27/2020 11:37:00 AM")
data.loc[data['SampleDate'] == "7/27/2020 11:37:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 7/27/2020 11:37:00 AM
#       Parameter                                Characteristic Sample_Fraction  \
# 50       TN_ugl                                      Nitrogen           Total
# 51    NH3_N_ugl                        Nitrogen, ammonia as N       Dissolved
# 52      NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N       Dissolved
# 53       TP_ugl                               Phosphorus as P           Total
# 54       OP_mgl              Phosphorus, phosphate (PO4) as P       Dissolved
# 55       DO_mgl                         Dissolved oxygen (DO)             NaN
# 56           pH                                            pH             NaN
# 57  Cond_umhocm                          Specific conductance             NaN
# 58      TempW_C                            Temperature, water             NaN
# 59      TempW_F                            Temperature, water             NaN
#
#     Result_Value Result_Unit
# 50      1090.000        ug/l
# ...

# %%
print("Parameters from 08-10-2020 11:16")
data.loc[data['SampleDate'] == "08-10-2020 11:16", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 08-10-2020 11:16
#       Parameter                                Characteristic Sample_Fraction  \
# 60       TN_ugl                                      Nitrogen           Total
# 61    NH3_N_ugl                        Nitrogen, ammonia as N       Dissolved
# 62      NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N       Dissolved
# 63       TP_ugl                               Phosphorus as P           Total
# 64       OP_mgl              Phosphorus, phosphate (PO4) as P       Dissolved
# 65       DO_mgl                         Dissolved oxygen (DO)             NaN
# 66           pH                                            pH             NaN
# 67  Cond_umhocm                          Specific conductance             NaN
# 68      TempW_C                            Temperature, water             NaN
# 69      TempW_F                            Temperature, water             NaN
#
#     Result_Value Result_Unit
# 60       771.000        ug/l
# ...

# %%
print("Parameters from 8/24/2020 11:36:00 AM")
data.loc[data['SampleDate'] == "8/24/2020 11:36:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 8/24/2020 11:36:00 AM
#       Parameter                                Characteristic Sample_Fraction  \
# 70       TN_ugl                                      Nitrogen           Total
# 71    NH3_N_ugl                        Nitrogen, ammonia as N       Dissolved
# 72      NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N       Dissolved
# 73       TP_ugl                               Phosphorus as P           Total
# 74       OP_mgl              Phosphorus, phosphate (PO4) as P       Dissolved
# 75       DO_mgl                         Dissolved oxygen (DO)             NaN
# 76           pH                                            pH             NaN
# 77  Cond_umhocm                          Specific conductance             NaN
# 78      TempW_C                            Temperature, water             NaN
# 79      TempW_F                            Temperature, water             NaN
#
#     Result_Value Result_Unit
# 70      1100.000        ug/l
# ...

# %%
print("Parameters from 09-08-2020 11:29")
data.loc[data['SampleDate'] == "09-08-2020 11:29", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 09-08-2020 11:29
#       Parameter                                Characteristic Sample_Fraction  \
# 80       TN_ugl                                      Nitrogen           Total
# 81    NH3_N_ugl                        Nitrogen, ammonia as N       Dissolved
# 82      NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N       Dissolved
# 83       TP_ugl                               Phosphorus as P           Total
# 84       OP_mgl              Phosphorus, phosphate (PO4) as P       Dissolved
# 85       DO_mgl                         Dissolved oxygen (DO)             NaN
# 86           pH                                            pH             NaN
# 87  Cond_umhocm                          Specific conductance             NaN
# 88      TempW_C                            Temperature, water             NaN
# 89      TempW_F                            Temperature, water             NaN
#
#     Result_Value Result_Unit
# 80      1060.000        ug/l
# ...

# %%
print("Parameters from 9/21/2020 11:43:00 AM")
data.loc[data['SampleDate'] == "9/21/2020 11:43:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 9/21/2020 11:43:00 AM
#       Parameter                                Characteristic Sample_Fraction  \
# 90       TN_ugl                                      Nitrogen           Total
# 91    NH3_N_ugl                        Nitrogen, ammonia as N       Dissolved
# 92      NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N       Dissolved
# 93       TP_ugl                               Phosphorus as P           Total
# 94       OP_mgl              Phosphorus, phosphate (PO4) as P       Dissolved
# 95       DO_mgl                         Dissolved oxygen (DO)             NaN
# 96           pH                                            pH             NaN
# 97  Cond_umhocm                          Specific conductance             NaN
# 98      TempW_C                            Temperature, water             NaN
# 99      TempW_F                            Temperature, water             NaN
#
#     Result_Value Result_Unit
# 90       1470.00        ug/l
# ...

# %%
print("Parameters from 10-05-2020 11:22")
data.loc[data['SampleDate'] == "10-05-2020 11:22", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 10-05-2020 11:22
#        Parameter                                Characteristic  \
# 100       TN_ugl                                      Nitrogen
# 101    NH3_N_ugl                        Nitrogen, ammonia as N
# 102      NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N
# 103       TP_ugl                               Phosphorus as P
# 104       OP_mgl              Phosphorus, phosphate (PO4) as P
# 105       DO_mgl                         Dissolved oxygen (DO)
# 106           pH                                            pH
# 107  Cond_umhocm                          Specific conductance
# 108      TempW_C                            Temperature, water
# 109      TempW_F                            Temperature, water
#
#     Sample_Fraction  Result_Value Result_Unit
# 100           Total      1310.000        ug/l
# 101       Dissolved       128.000        ug/l
# 102       Dissolved       112.000        ug/l
# 103           Total       180.000        ug/l
# ...

# %%
print("Parameters from 10/19/2020 12:16:00 PM")
data.loc[data['SampleDate'] == "10/19/2020 12:16:00 PM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 10/19/2020 12:16:00 PM
#        Parameter                                Characteristic  \
# 110       TN_ugl                                      Nitrogen
# 111    NH3_N_ugl                        Nitrogen, ammonia as N
# 112      NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N
# 113       TP_ugl                               Phosphorus as P
# 114       OP_mgl              Phosphorus, phosphate (PO4) as P
# 115       DO_mgl                         Dissolved oxygen (DO)
# 116           pH                                            pH
# 117  Cond_umhocm                          Specific conductance
# 118      TempW_C                            Temperature, water
# 119      TempW_F                            Temperature, water
#
#     Sample_Fraction  Result_Value Result_Unit
# 110           Total       1200.00        ug/l
# 111       Dissolved         40.00        ug/l
# 112       Dissolved        107.00        ug/l
# ...

# %%
print("Parameters from 11-02-2020 11:46")
data.loc[data['SampleDate'] == "11-02-2020 11:46", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 11-02-2020 11:46
#        Parameter                                Characteristic  \
# 120       TN_ugl                                      Nitrogen
# 121    NH3_N_ugl                        Nitrogen, ammonia as N
# 122      NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N
# 123       TP_ugl                               Phosphorus as P
# 124       OP_mgl              Phosphorus, phosphate (PO4) as P
# 125       DO_mgl                         Dissolved oxygen (DO)
# 126           pH                                            pH
# 127  Cond_umhocm                          Specific conductance
# 128      TempW_C                            Temperature, water
# 129      TempW_F                            Temperature, water
#
#     Sample_Fraction  Result_Value Result_Unit
# 120           Total      1220.000        ug/l
# 121       Dissolved        21.000        ug/l
# 122       Dissolved         9.000        ug/l
# 123           Total        74.000        ug/l
# ...

# %%
print("Parameters from 11/16/2020 11:44:00 AM")
data.loc[data['SampleDate'] == "11/16/2020 11:44:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 11/16/2020 11:44:00 AM
#        Parameter                                Characteristic  \
# 130       TN_ugl                                      Nitrogen
# 131    NH3_N_ugl                        Nitrogen, ammonia as N
# 132      NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N
# 133       TP_ugl                               Phosphorus as P
# 134       OP_mgl              Phosphorus, phosphate (PO4) as P
# 135       DO_mgl                         Dissolved oxygen (DO)
# 136           pH                                            pH
# 137  Cond_umhocm                          Specific conductance
# 138      TempW_C                            Temperature, water
# 139      TempW_F                            Temperature, water
#
#     Sample_Fraction  Result_Value Result_Unit
# 130           Total       1510.00        ug/l
# 131       Dissolved        140.00        ug/l
# 132       Dissolved        247.00        ug/l
# ...

# %%
print("Parameters from 11/30/2020 10:52:00 AM")
data.loc[data['SampleDate'] == "11/30/2020 10:52:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 11/30/2020 10:52:00 AM
#        Parameter                                Characteristic  \
# 140       TN_ugl                                      Nitrogen
# 141    NH3_N_ugl                        Nitrogen, ammonia as N
# 142      NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N
# 143       TP_ugl                               Phosphorus as P
# 144       OP_mgl              Phosphorus, phosphate (PO4) as P
# 145       DO_mgl                         Dissolved oxygen (DO)
# 146           pH                                            pH
# 147  Cond_umhocm                          Specific conductance
# 148      TempW_C                            Temperature, water
# 149      TempW_F                            Temperature, water
#
#     Sample_Fraction  Result_Value Result_Unit
# 140           Total       1430.00        ug/l
# 141       Dissolved         24.00        ug/l
# 142       Dissolved        181.00        ug/l
# ...

# %%
print("Parameters from 12/14/2020 11:20:00 AM")
data.loc[data['SampleDate'] == "12/14/2020 11:20:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 12/14/2020 11:20:00 AM
#        Parameter                                Characteristic  \
# 150       TN_ugl                                      Nitrogen
# 151    NH3_N_ugl                        Nitrogen, ammonia as N
# 152      NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N
# 153       TP_ugl                               Phosphorus as P
# 154       OP_mgl              Phosphorus, phosphate (PO4) as P
# 155       DO_mgl                         Dissolved oxygen (DO)
# 156           pH                                            pH
# 157  Cond_umhocm                          Specific conductance
# 158      TempW_C                            Temperature, water
# 159      TempW_F                            Temperature, water
#
#     Sample_Fraction  Result_Value Result_Unit
# 150           Total      1150.000        ug/l
# 151       Dissolved        20.000        ug/l
# 152       Dissolved         5.000        ug/l
# ...

# %%
print("Parameters from 12/28/2020 11:05:00 AM")
data.loc[data['SampleDate'] == "12/28/2020 11:05:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 12/28/2020 11:05:00 AM
#        Parameter                                Characteristic  \
# 160       TN_ugl                                      Nitrogen
# 161    NH3_N_ugl                        Nitrogen, ammonia as N
# 162      NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N
# 163       TP_ugl                               Phosphorus as P
# 164       OP_mgl              Phosphorus, phosphate (PO4) as P
# 165       DO_mgl                         Dissolved oxygen (DO)
# 166           pH                                            pH
# 167  Cond_umhocm                          Specific conductance
# 168      TempW_C                            Temperature, water
# 169      TempW_F                            Temperature, water
#
#     Sample_Fraction  Result_Value Result_Unit
# 160           Total      1040.000        ug/l
# 161       Dissolved        23.000        ug/l
# 162       Dissolved        29.000        ug/l
# ...

# %%
print("Parameters from 01-11-2021 12:08")
data.loc[data['SampleDate'] == "01-11-2021 12:08", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 01-11-2021 12:08
#        Parameter                                Characteristic  \
# 170       TN_ugl                                      Nitrogen
# 171    NH3_N_ugl                        Nitrogen, ammonia as N
# 172      NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N
# 173       TP_ugl                               Phosphorus as P
# 174       OP_mgl              Phosphorus, phosphate (PO4) as P
# 175       DO_mgl                         Dissolved oxygen (DO)
# 176           pH                                            pH
# 177  Cond_umhocm                          Specific conductance
# 178      TempW_C                            Temperature, water
# 179      TempW_F                            Temperature, water
#
#     Sample_Fraction  Result_Value Result_Unit
# 170           Total       987.000        ug/l
# 171       Dissolved        16.000        ug/l
# 172       Dissolved        12.000        ug/l
# 173           Total        48.000        ug/l
# ...

# %%
print("Parameters from 1/25/2021 11:30:00 AM")
data.loc[data['SampleDate'] == "1/25/2021 11:30:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 1/25/2021 11:30:00 AM
#        Parameter                                Characteristic  \
# 180       TN_ugl                                      Nitrogen
# 181    NH3_N_ugl                        Nitrogen, ammonia as N
# 182      NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N
# 183       TP_ugl                               Phosphorus as P
# 184       OP_mgl              Phosphorus, phosphate (PO4) as P
# 185       DO_mgl                         Dissolved oxygen (DO)
# 186           pH                                            pH
# 187  Cond_umhocm                          Specific conductance
# 188      TempW_C                            Temperature, water
# 189      TempW_F                            Temperature, water
#
#     Sample_Fraction  Result_Value Result_Unit
# 180           Total       928.000        ug/l
# 181       Dissolved        23.000        ug/l
# 182       Dissolved         5.000        ug/l
# 183           Total        47.000        ug/l
# ...

# %%
print("Parameters from 02-08-2021 11:06")
data.loc[data['SampleDate'] == "02-08-2021 11:06", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 02-08-2021 11:06
#        Parameter                                Characteristic  \
# 190       TN_ugl                                      Nitrogen
# 191    NH3_N_ugl                        Nitrogen, ammonia as N
# 192      NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N
# 193       TP_ugl                               Phosphorus as P
# 194       OP_mgl              Phosphorus, phosphate (PO4) as P
# 195       DO_mgl                         Dissolved oxygen (DO)
# 196           pH                                            pH
# 197  Cond_umhocm                          Specific conductance
# 198      TempW_C                            Temperature, water
# 199      TempW_F                            Temperature, water
#
#     Sample_Fraction  Result_Value Result_Unit
# 190           Total       879.000        ug/l
# 191       Dissolved        30.000        ug/l
# 192       Dissolved         5.000        ug/l
# 193           Total        43.000        ug/l
# ...

# %%
print("Parameters from 2/22/2021 10:58:00 AM")
data.loc[data['SampleDate'] == "2/22/2021 10:58:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 2/22/2021 10:58:00 AM
#        Parameter                                Characteristic  \
# 200       TN_ugl                                      Nitrogen
# 201    NH3_N_ugl                        Nitrogen, ammonia as N
# 202      NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N
# 203       TP_ugl                               Phosphorus as P
# 204       OP_mgl              Phosphorus, phosphate (PO4) as P
# 205       DO_mgl                         Dissolved oxygen (DO)
# 206           pH                                            pH
# 207  Cond_umhocm                          Specific conductance
# 208      TempW_C                            Temperature, water
# 209      TempW_F                            Temperature, water
#
#     Sample_Fraction  Result_Value Result_Unit
# 200           Total       897.000        ug/l
# 201       Dissolved        15.000        ug/l
# 202       Dissolved         5.000        ug/l
# 203           Total        46.000        ug/l
# ...

# %%
print("Parameters from 3/22/2021 11:34:00 AM")
data.loc[data['SampleDate'] == "3/22/2021 11:34:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 3/22/2021 11:34:00 AM
#        Parameter                                Characteristic  \
# 210       TN_ugl                                      Nitrogen
# 211    NH3_N_ugl                        Nitrogen, ammonia as N
# 212      NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N
# 213       TP_ugl                               Phosphorus as P
# 214       OP_mgl              Phosphorus, phosphate (PO4) as P
# 215       DO_mgl                         Dissolved oxygen (DO)
# 216           pH                                            pH
# 217  Cond_umhocm                          Specific conductance
# 218      TempW_C                            Temperature, water
# 219      TempW_F                            Temperature, water
#
#     Sample_Fraction  Result_Value Result_Unit
# 210           Total      1080.000        ug/l
# 211       Dissolved        44.000        ug/l
# 212       Dissolved         5.000        ug/l
# 213           Total        64.000        ug/l
# ...

# %%
print("Parameters from 04-05-2021 11:15")
data.loc[data['SampleDate'] == "04-05-2021 11:15", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 04-05-2021 11:15
#        Parameter                                Characteristic  \
# 220       TN_ugl                                      Nitrogen
# 221    NH3_N_ugl                        Nitrogen, ammonia as N
# 222      NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N
# 223       TP_ugl                               Phosphorus as P
# 224       OP_mgl              Phosphorus, phosphate (PO4) as P
# 225       DO_mgl                         Dissolved oxygen (DO)
# 226           pH                                            pH
# 227  Cond_umhocm                          Specific conductance
# 228      TempW_C                            Temperature, water
# 229      TempW_F                            Temperature, water
#
#     Sample_Fraction  Result_Value Result_Unit
# 220           Total      1210.000        ug/l
# 221       Dissolved       303.000        ug/l
# 222       Dissolved        15.000        ug/l
# 223           Total        56.000        ug/l
# ...

# %%
print("Parameters from 4/19/2021 10:21:00 AM")
data.loc[data['SampleDate'] == "4/19/2021 10:21:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 4/19/2021 10:21:00 AM
#        Parameter                                Characteristic  \
# 230       TN_ugl                                      Nitrogen
# 231    NH3_N_ugl                        Nitrogen, ammonia as N
# 232      NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N
# 233       TP_ugl                               Phosphorus as P
# 234       OP_mgl              Phosphorus, phosphate (PO4) as P
# 235       DO_mgl                         Dissolved oxygen (DO)
# 236           pH                                            pH
# 237  Cond_umhocm                          Specific conductance
# 238      TempW_C                            Temperature, water
# 239      TempW_F                            Temperature, water
#
#     Sample_Fraction  Result_Value Result_Unit
# 230           Total      1070.000        ug/l
# 231       Dissolved        70.000        ug/l
# 232       Dissolved         7.000        ug/l
# 233           Total        59.000        ug/l
# ...

# %%
print("Parameters from 05-03-2021 10:54")
data.loc[data['SampleDate'] == "05-03-2021 10:54", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 05-03-2021 10:54
#        Parameter                                Characteristic  \
# 240       TN_ugl                                      Nitrogen
# 241    NH3_N_ugl                        Nitrogen, ammonia as N
# 242      NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N
# 243       TP_ugl                               Phosphorus as P
# 244       OP_mgl              Phosphorus, phosphate (PO4) as P
# 245       DO_mgl                         Dissolved oxygen (DO)
# 246           pH                                            pH
# 247  Cond_umhocm                          Specific conductance
# 248      TempW_C                            Temperature, water
# 249      TempW_F                            Temperature, water
#
#     Sample_Fraction  Result_Value Result_Unit
# 240           Total      1070.000        ug/l
# 241       Dissolved        61.000        ug/l
# 242       Dissolved         7.000        ug/l
# 243           Total        62.000        ug/l
# ...

# %%
print("Parameters from 1/24/2018 9:10:00 AM")
data.loc[data['SampleDate'] == "1/24/2018 9:10:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 1/24/2018 9:10:00 AM
#           Parameter                                     Characteristic  \
# 250   Alk_CaCO3_mgl  Alkalinity, Total (total hydroxide+carbonate+b...
# 251          As_ugl                                            Arsenic
# 252          Cd_ugl                                            Cadmium
# 253          Ca_mgl                                            Calcium
# 254   C_organic_mgl                                    Carbon, organic
# 255          Cl_mgl                                           Chloride
# 256       ChlaC_ugl            Chlorophyll a, corrected for pheophytin
# 257        Chla_ugl          Chlorophyll a, uncorrected for pheophytin
# 258          Cr_ugl                                           Chromium
# 259          Cu_ugl                                             Copper
# 260         TDS_mgl                                   Dissolved Solids
# 261     Ecoli_100ml                                   Escherichia coli
# ...

# %%
print("Parameters from 03-05-2018 10:10")
data.loc[data['SampleDate'] == "03-05-2018 10:10", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 03-05-2018 10:10
#           Parameter                                     Characteristic  \
# 289          TN_ugl                                           Nitrogen
# 290   Alk_CaCO3_mgl  Alkalinity, Total (total hydroxide+carbonate+b...
# 291          As_ugl                                            Arsenic
# 292          Cd_ugl                                            Cadmium
# 293          Ca_mgl                                            Calcium
# 294   C_organic_mgl                                    Carbon, organic
# 295          Cl_mgl                                           Chloride
# 296       ChlaC_ugl            Chlorophyll a, corrected for pheophytin
# 297        Chla_ugl          Chlorophyll a, uncorrected for pheophytin
# 298          Cr_ugl                                           Chromium
# 299          Cu_ugl                                             Copper
# 300         TDS_mgl                                   Dissolved Solids
# ...

# %%
print("Parameters from 5/15/2018 11:55:00 AM")
data.loc[data['SampleDate'] == "5/15/2018 11:55:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 5/15/2018 11:55:00 AM
#           Parameter                                     Characteristic  \
# 328   Alk_CaCO3_mgl  Alkalinity, Total (total hydroxide+carbonate+b...
# 329          As_ugl                                            Arsenic
# 330          Cd_ugl                                            Cadmium
# 331          Ca_mgl                                            Calcium
# 332   C_organic_mgl                                    Carbon, organic
# 333          Cl_mgl                                           Chloride
# 334       ChlaC_ugl            Chlorophyll a, corrected for pheophytin
# 335        Chla_ugl          Chlorophyll a, uncorrected for pheophytin
# 336          Cr_ugl                                           Chromium
# 337          Cu_ugl                                             Copper
# 338         TDS_mgl                                   Dissolved Solids
# 339     Ecoli_100ml                                   Escherichia coli
# ...

# %%
print("Parameters from 06-07-2018 9:00")
data.loc[data['SampleDate'] == "06-07-2018 9:00", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 06-07-2018 9:00
#           Parameter                                     Characteristic  \
# 369          TN_ugl                                           Nitrogen
# 370   Alk_CaCO3_mgl  Alkalinity, Total (total hydroxide+carbonate+b...
# 371          As_ugl                                            Arsenic
# 372          Cd_ugl                                            Cadmium
# 373          Ca_mgl                                            Calcium
# 374   C_organic_mgl                                    Carbon, organic
# 375          Cl_mgl                                           Chloride
# 376       ChlaC_ugl            Chlorophyll a, corrected for pheophytin
# 377        Chla_ugl          Chlorophyll a, uncorrected for pheophytin
# 378          Cr_ugl                                           Chromium
# 379          Cu_ugl                                             Copper
# 380         TDS_mgl                                   Dissolved Solids
# ...

# %%
print("Parameters from 7/24/2018 12:30:00 PM")
data.loc[data['SampleDate'] == "7/24/2018 12:30:00 PM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 7/24/2018 12:30:00 PM
#           Parameter                                     Characteristic  \
# 408   Alk_CaCO3_mgl  Alkalinity, Total (total hydroxide+carbonate+b...
# 409          As_ugl                                            Arsenic
# 410          Cd_ugl                                            Cadmium
# 411          Ca_mgl                                            Calcium
# 412   C_organic_mgl                                    Carbon, organic
# 413          Cl_mgl                                           Chloride
# 414       ChlaC_ugl            Chlorophyll a, corrected for pheophytin
# 415        Chla_ugl          Chlorophyll a, uncorrected for pheophytin
# 416          Cr_ugl                                           Chromium
# 417          Cu_ugl                                             Copper
# 418         TDS_mgl                                   Dissolved Solids
# 419     Ecoli_100ml                                   Escherichia coli
# ...

# %%
print("Parameters from 09-11-2018 14:00")
data.loc[data['SampleDate'] == "09-11-2018 14:00", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 09-11-2018 14:00
#           Parameter                                     Characteristic  \
# 447          TN_ugl                                           Nitrogen
# 448   Alk_CaCO3_mgl  Alkalinity, Total (total hydroxide+carbonate+b...
# 449          As_ugl                                            Arsenic
# 450          Cd_ugl                                            Cadmium
# 451          Ca_mgl                                            Calcium
# 452   C_organic_mgl                                    Carbon, organic
# 453          Cl_mgl                                           Chloride
# 454       ChlaC_ugl            Chlorophyll a, corrected for pheophytin
# 455        Chla_ugl          Chlorophyll a, uncorrected for pheophytin
# 456          Cr_ugl                                           Chromium
# 457          Cu_ugl                                             Copper
# 458         TDS_mgl                                   Dissolved Solids
# ...

# %%
print("Parameters from 12-12-2018 15:10")
data.loc[data['SampleDate'] == "12-12-2018 15:10", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 12-12-2018 15:10
#           Parameter                                     Characteristic  \
# 488   Alk_CaCO3_mgl  Alkalinity, Total (total hydroxide+carbonate+b...
# 489          As_ugl                                            Arsenic
# 490          Cd_ugl                                            Cadmium
# 491          Ca_mgl                                            Calcium
# 492   C_organic_mgl                                    Carbon, organic
# 493          Cl_mgl                                           Chloride
# 494       ChlaC_ugl            Chlorophyll a, corrected for pheophytin
# 495        Chla_ugl          Chlorophyll a, uncorrected for pheophytin
# 496          Cr_ugl                                           Chromium
# 497          Cu_ugl                                             Copper
# 498         TDS_mgl                                   Dissolved Solids
# 499     Ecoli_100ml                                   Escherichia coli
# ...

# %%
print("Parameters from 04-09-2019 10:00")
data.loc[data['SampleDate'] == "04-09-2019 10:00", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 04-09-2019 10:00
#           Parameter                                     Characteristic  \
# 529          TN_ugl                                           Nitrogen
# 530         24D_ugl             2,4-Dichlorophenoxyacetic acid (2,4-D)
# 531   Alk_CaCO3_mgl  Alkalinity, Total (total hydroxide+carbonate+b...
# 532          Al_ugl                                           Aluminum
# 533          Sb_ugl                                           Antimony
# 534          As_ugl                                            Arsenic
# 535          Ba_ugl                                             Barium
# 536           B_ugl                                              Boron
# 537          Cd_ugl                                            Cadmium
# 538          Ca_mgl                                            Calcium
# 539   C_organic_mgl                                    Carbon, organic
# 540          Cl_mgl                                           Chloride
# ...

# %%
print("Parameters from 05-07-2019 10:40")
data.loc[data['SampleDate'] == "05-07-2019 10:40", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 05-07-2019 10:40
#           Parameter                                     Characteristic  \
# 582         24D_ugl             2,4-Dichlorophenoxyacetic acid (2,4-D)
# 583   Alk_CaCO3_mgl  Alkalinity, Total (total hydroxide+carbonate+b...
# 584          Al_ugl                                           Aluminum
# 585          Sb_ugl                                           Antimony
# 586          As_ugl                                            Arsenic
# 587          Ba_ugl                                             Barium
# 588           B_ugl                                              Boron
# 589          Cd_ugl                                            Cadmium
# 590          Ca_mgl                                            Calcium
# 591   C_organic_mgl                                    Carbon, organic
# 592          Cl_mgl                                           Chloride
# 593       ChlaC_ugl            Chlorophyll a, corrected for pheophytin
# ...

# %%
print("Parameters from 6/24/2019 10:15:00 AM")
data.loc[data['SampleDate'] == "6/24/2019 10:15:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 6/24/2019 10:15:00 AM
#           Parameter                                     Characteristic  \
# 636          TN_ugl                                           Nitrogen
# 637         24D_ugl             2,4-Dichlorophenoxyacetic acid (2,4-D)
# 638   Alk_CaCO3_mgl  Alkalinity, Total (total hydroxide+carbonate+b...
# 639          Al_ugl                                           Aluminum
# 640          Sb_ugl                                           Antimony
# 641          As_ugl                                            Arsenic
# 642          Ba_ugl                                             Barium
# 643           B_ugl                                              Boron
# 644          Cd_ugl                                            Cadmium
# 645          Ca_mgl                                            Calcium
# 646   C_organic_mgl                                    Carbon, organic
# 647          Cl_mgl                                           Chloride
# ...

# %%
print("Parameters from 7/15/2019 11:00:00 AM")
data.loc[data['SampleDate'] == "7/15/2019 11:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 7/15/2019 11:00:00 AM
#           Parameter                                     Characteristic  \
# 726          TN_ugl                                           Nitrogen
# 727         24D_ugl             2,4-Dichlorophenoxyacetic acid (2,4-D)
# 728   Alk_CaCO3_mgl  Alkalinity, Total (total hydroxide+carbonate+b...
# 729          Al_ugl                                           Aluminum
# 730          Sb_ugl                                           Antimony
# 731          As_ugl                                            Arsenic
# 732          Ba_ugl                                             Barium
# 733           B_ugl                                              Boron
# 734          Cd_ugl                                            Cadmium
# 735          Ca_mgl                                            Calcium
# 736   C_organic_mgl                                    Carbon, organic
# 737          Cl_mgl                                           Chloride
# ...

# %%
print("Parameters from 10-02-2019 10:25")
data.loc[data['SampleDate'] == "10-02-2019 10:25", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 10-02-2019 10:25
#           Parameter                                     Characteristic  \
# 780         24D_ugl             2,4-Dichlorophenoxyacetic acid (2,4-D)
# 781   Alk_CaCO3_mgl  Alkalinity, Total (total hydroxide+carbonate+b...
# 782          Al_ugl                                           Aluminum
# 783          Sb_ugl                                           Antimony
# 784          As_ugl                                            Arsenic
# 785          Ba_ugl                                             Barium
# 786           B_ugl                                              Boron
# 787          Cd_ugl                                            Cadmium
# 788          Ca_mgl                                            Calcium
# 789   C_organic_mgl                                    Carbon, organic
# 790          Cl_mgl                                           Chloride
# 791       ChlaC_ugl            Chlorophyll a, corrected for pheophytin
# ...

# %%
print("Parameters from 2/14/2013 12:00:00 AM")
data.loc[data['SampleDate'] == "2/14/2013 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 2/14/2013 12:00:00 AM
#         Parameter               Characteristic Sample_Fraction  Result_Value  \
# 834       TempW_C           Temperature, water             NaN      22.64000
# 835   Cond_umhocm         Specific conductance             NaN     712.00000
# 836     Secchi_ft            Secchi disk depth             NaN       0.98424
# 837            pH                           pH             NaN       7.60000
# 838   Fe_diss_ugl                         Iron       Dissolved      92.00000
# 839    DO_percent  Dissolved oxygen saturation             NaN      99.40000
# 840        DO_mgl        Dissolved oxygen (DO)             NaN       8.57000
# 841       TempW_F           Temperature, water             NaN      72.75200
# 1088      TempW_F           Temperature, water             NaN      73.22000
# 1089      TempW_C           Temperature, water             NaN      22.90000
# 1090  Cond_umhocm         Specific conductance             NaN     654.00000
# ...

# %%
print("Parameters from 04-03-2013 0:00")
data.loc[data['SampleDate'] == "04-03-2013 0:00", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 04-03-2013 0:00
#         Parameter               Characteristic Sample_Fraction  Result_Value  \
# 842       TempW_C           Temperature, water             NaN      26.07000
# 843   Cond_umhocm         Specific conductance             NaN     582.00000
# 844     Secchi_ft            Secchi disk depth             NaN       0.98424
# 845            pH                           pH             NaN       7.52000
# 846   Fe_diss_ugl                         Iron       Dissolved     120.00000
# 847    DO_percent  Dissolved oxygen saturation             NaN     118.90000
# 848        DO_mgl        Dissolved oxygen (DO)             NaN       9.62000
# 849       TempW_F           Temperature, water             NaN      78.92600
# 1096      TempW_F           Temperature, water             NaN      78.56600
# 1097  Cond_umhocm         Specific conductance             NaN     583.00000
# 1098      TempW_C           Temperature, water             NaN      25.87000
# ...

# %%
print("Parameters from 6/26/2013 12:00:00 AM")
data.loc[data['SampleDate'] == "6/26/2013 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 6/26/2013 12:00:00 AM
#         Parameter               Characteristic Sample_Fraction  Result_Value  \
# 850       TempW_C           Temperature, water             NaN      30.16000
# 851   Cond_umhocm         Specific conductance             NaN     447.00000
# 852     Secchi_ft            Secchi disk depth             NaN       1.64040
# 853            pH                           pH             NaN       7.53000
# 854   Fe_diss_ugl                         Iron       Dissolved     260.00000
# 855    DO_percent  Dissolved oxygen saturation             NaN     177.50000
# 856        DO_mgl        Dissolved oxygen (DO)             NaN      13.36000
# 857       TempW_F           Temperature, water             NaN      86.28800
# 1104       DO_mgl        Dissolved oxygen (DO)             NaN      12.27000
# 1105   DO_percent  Dissolved oxygen saturation             NaN     163.50000
# 1106  Fe_diss_ugl                         Iron       Dissolved     150.00000
# ...

# %%
print("Parameters from 8/20/2013 12:00:00 AM")
data.loc[data['SampleDate'] == "8/20/2013 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 8/20/2013 12:00:00 AM
#           Parameter               Characteristic  Sample_Fraction  \
# 858         TempW_C           Temperature, water              NaN
# 859     Cond_umhocm         Specific conductance              NaN
# 860       Secchi_ft            Secchi disk depth              NaN
# 861              pH                           pH              NaN
# 862          Fe_ugl                         Iron  Total Recovrble
# 863      DO_percent  Dissolved oxygen saturation              NaN
# 864          DO_mgl        Dissolved oxygen (DO)              NaN
# 865   Depth_bott_ft                Depth, bottom              NaN
# 866         TempW_F           Temperature, water              NaN
# 1112        TempW_F           Temperature, water              NaN
# 1113  Depth_bott_ft                Depth, bottom              NaN
# 1114         DO_mgl        Dissolved oxygen (DO)              NaN
# 1115     DO_percent  Dissolved oxygen saturation              NaN
# ...

# %%
print("Parameters from 4/24/2017 10:50:00 AM")
data.loc[data['SampleDate'] == "4/24/2017 10:50:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 4/24/2017 10:50:00 AM
#           Parameter                                     Characteristic  \
# 867   Alk_CaCO3_mgl  Alkalinity, Total (total hydroxide+carbonate+b...
# 868          As_ugl                                            Arsenic
# 869          Cd_ugl                                            Cadmium
# 870          Ca_mgl                                            Calcium
# 871   C_organic_mgl                                    Carbon, organic
# 872          Cl_mgl                                           Chloride
# 873       ChlaC_ugl            Chlorophyll a, corrected for pheophytin
# 874        Chla_ugl          Chlorophyll a, uncorrected for pheophytin
# 875          Cr_ugl                                           Chromium
# 876          Cu_ugl                                             Copper
# 877         TDS_mgl                                   Dissolved Solids
# 878           F_mgl                                          Fluorides
# ...

# %%
print("Parameters from 07-12-2017 9:40")
data.loc[data['SampleDate'] == "07-12-2017 9:40", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 07-12-2017 9:40
#           Parameter                                     Characteristic  \
# 905          TN_ugl                                           Nitrogen
# 906   Alk_CaCO3_mgl  Alkalinity, Total (total hydroxide+carbonate+b...
# 907          As_ugl                                            Arsenic
# 908          Cd_ugl                                            Cadmium
# 909          Ca_mgl                                            Calcium
# 910   C_organic_mgl                                    Carbon, organic
# 911          Cl_mgl                                           Chloride
# 912       ChlaC_ugl            Chlorophyll a, corrected for pheophytin
# 913        Chla_ugl          Chlorophyll a, uncorrected for pheophytin
# 914          Cr_ugl                                           Chromium
# 915          Cu_ugl                                             Copper
# 916         TDS_mgl                                   Dissolved Solids
# ...

# %%
print("Parameters from 8/28/2017 11:00:00 AM")
data.loc[data['SampleDate'] == "8/28/2017 11:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 8/28/2017 11:00:00 AM
#           Parameter                                     Characteristic  \
# 943   Alk_CaCO3_mgl  Alkalinity, Total (total hydroxide+carbonate+b...
# 944          As_ugl                                            Arsenic
# 945          Cd_ugl                                            Cadmium
# 946          Ca_mgl                                            Calcium
# 947   C_organic_mgl                                    Carbon, organic
# 948          Cl_mgl                                           Chloride
# 949       ChlaC_ugl            Chlorophyll a, corrected for pheophytin
# 950        Chla_ugl          Chlorophyll a, uncorrected for pheophytin
# 951          Cr_ugl                                           Chromium
# 952          Cu_ugl                                             Copper
# 953         TDS_mgl                                   Dissolved Solids
# 954           F_mgl                                          Fluorides
# ...

# %%
print("Parameters from 10/17/2017 2:10:00 PM")
data.loc[data['SampleDate'] == "10/17/2017 2:10:00 PM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 10/17/2017 2:10:00 PM
#            Parameter                                     Characteristic  \
# 981           TN_ugl                                           Nitrogen
# 982    Alk_CaCO3_mgl  Alkalinity, Total (total hydroxide+carbonate+b...
# 983           As_ugl                                            Arsenic
# 984           Cd_ugl                                            Cadmium
# 985           Ca_mgl                                            Calcium
# 986    C_organic_mgl                                    Carbon, organic
# 987           Cl_mgl                                           Chloride
# 988        ChlaC_ugl            Chlorophyll a, corrected for pheophytin
# 989         Chla_ugl          Chlorophyll a, uncorrected for pheophytin
# 990           Cr_ugl                                           Chromium
# 991           Cu_ugl                                             Copper
# ...

# %%
print("Parameters from 11/14/2017 1:50:00 PM")
data.loc[data['SampleDate'] == "11/14/2017 1:50:00 PM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 11/14/2017 1:50:00 PM
#            Parameter                                     Characteristic  \
# 1050          TN_ugl                                           Nitrogen
# 1051   Alk_CaCO3_mgl  Alkalinity, Total (total hydroxide+carbonate+b...
# 1052          As_ugl                                            Arsenic
# 1053          Cd_ugl                                            Cadmium
# 1054          Ca_mgl                                            Calcium
# 1055   C_organic_mgl                                    Carbon, organic
# 1056          Cl_mgl                                           Chloride
# 1057       ChlaC_ugl            Chlorophyll a, corrected for pheophytin
# 1058        Chla_ugl          Chlorophyll a, uncorrected for pheophytin
# 1059          Cr_ugl                                           Chromium
# 1060          Cu_ugl                                             Copper
# ...

# %%
print("Parameters from 2/14/2013 12:00:00 AM")
data.loc[data['SampleDate'] == "2/14/2013 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 2/14/2013 12:00:00 AM
#         Parameter               Characteristic Sample_Fraction  Result_Value  \
# 834       TempW_C           Temperature, water             NaN      22.64000
# 835   Cond_umhocm         Specific conductance             NaN     712.00000
# 836     Secchi_ft            Secchi disk depth             NaN       0.98424
# 837            pH                           pH             NaN       7.60000
# 838   Fe_diss_ugl                         Iron       Dissolved      92.00000
# 839    DO_percent  Dissolved oxygen saturation             NaN      99.40000
# 840        DO_mgl        Dissolved oxygen (DO)             NaN       8.57000
# 841       TempW_F           Temperature, water             NaN      72.75200
# 1088      TempW_F           Temperature, water             NaN      73.22000
# 1089      TempW_C           Temperature, water             NaN      22.90000
# 1090  Cond_umhocm         Specific conductance             NaN     654.00000
# ...

# %%
print("Parameters from 04-03-2013 0:00")
data.loc[data['SampleDate'] == "04-03-2013 0:00", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 04-03-2013 0:00
#         Parameter               Characteristic Sample_Fraction  Result_Value  \
# 842       TempW_C           Temperature, water             NaN      26.07000
# 843   Cond_umhocm         Specific conductance             NaN     582.00000
# 844     Secchi_ft            Secchi disk depth             NaN       0.98424
# 845            pH                           pH             NaN       7.52000
# 846   Fe_diss_ugl                         Iron       Dissolved     120.00000
# 847    DO_percent  Dissolved oxygen saturation             NaN     118.90000
# 848        DO_mgl        Dissolved oxygen (DO)             NaN       9.62000
# 849       TempW_F           Temperature, water             NaN      78.92600
# 1096      TempW_F           Temperature, water             NaN      78.56600
# 1097  Cond_umhocm         Specific conductance             NaN     583.00000
# 1098      TempW_C           Temperature, water             NaN      25.87000
# ...

# %%
print("Parameters from 6/26/2013 12:00:00 AM")
data.loc[data['SampleDate'] == "6/26/2013 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 6/26/2013 12:00:00 AM
#         Parameter               Characteristic Sample_Fraction  Result_Value  \
# 850       TempW_C           Temperature, water             NaN      30.16000
# 851   Cond_umhocm         Specific conductance             NaN     447.00000
# 852     Secchi_ft            Secchi disk depth             NaN       1.64040
# 853            pH                           pH             NaN       7.53000
# 854   Fe_diss_ugl                         Iron       Dissolved     260.00000
# 855    DO_percent  Dissolved oxygen saturation             NaN     177.50000
# 856        DO_mgl        Dissolved oxygen (DO)             NaN      13.36000
# 857       TempW_F           Temperature, water             NaN      86.28800
# 1104       DO_mgl        Dissolved oxygen (DO)             NaN      12.27000
# 1105   DO_percent  Dissolved oxygen saturation             NaN     163.50000
# 1106  Fe_diss_ugl                         Iron       Dissolved     150.00000
# ...

# %%
print("Parameters from 8/20/2013 12:00:00 AM  ")
data.loc[data['SampleDate'] == "8/20/2013 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 8/20/2013 12:00:00 AM
#           Parameter               Characteristic  Sample_Fraction  \
# 858         TempW_C           Temperature, water              NaN
# 859     Cond_umhocm         Specific conductance              NaN
# 860       Secchi_ft            Secchi disk depth              NaN
# 861              pH                           pH              NaN
# 862          Fe_ugl                         Iron  Total Recovrble
# 863      DO_percent  Dissolved oxygen saturation              NaN
# 864          DO_mgl        Dissolved oxygen (DO)              NaN
# 865   Depth_bott_ft                Depth, bottom              NaN
# 866         TempW_F           Temperature, water              NaN
# 1112        TempW_F           Temperature, water              NaN
# 1113  Depth_bott_ft                Depth, bottom              NaN
# 1114         DO_mgl        Dissolved oxygen (DO)              NaN
# 1115     DO_percent  Dissolved oxygen saturation              NaN
# ...

# %%
print("Parameters from 9/19/2013 12:00:00 AM")
data.loc[data['SampleDate'] == "9/19/2013 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 9/19/2013 12:00:00 AM
#           Parameter               Characteristic  Sample_Fraction  \
# 1121  Depth_bott_ft                Depth, bottom              NaN
# 1122         DO_mgl        Dissolved oxygen (DO)              NaN
# 1123     DO_percent  Dissolved oxygen saturation              NaN
# 1124         Fe_ugl                         Iron  Total Recovrble
# 1125             pH                           pH              NaN
# 1126      Secchi_ft            Secchi disk depth              NaN
# 1127    Cond_umhocm         Specific conductance              NaN
# 1128        TempW_C           Temperature, water              NaN
# 1129        TempW_F           Temperature, water              NaN
# 2271        TempW_F           Temperature, water              NaN
# 2272  Depth_bott_ft                Depth, bottom              NaN
# 2273         DO_mgl        Dissolved oxygen (DO)              NaN
# 2274     DO_percent  Dissolved oxygen saturation              NaN
# ...

# %%
print("Parameters from 10/16/2013 12:00:00 AM")
data.loc[data['SampleDate'] == "10/16/2013 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 10/16/2013 12:00:00 AM
#           Parameter               Characteristic  Sample_Fraction  \
# 1130        TempW_F           Temperature, water              NaN
# 1131  Depth_bott_ft                Depth, bottom              NaN
# 1132         DO_mgl        Dissolved oxygen (DO)              NaN
# 1133     DO_percent  Dissolved oxygen saturation              NaN
# 1134         Fe_ugl                         Iron  Total Recovrble
# 1135             pH                           pH              NaN
# 1136      Secchi_ft            Secchi disk depth              NaN
# 1137    Cond_umhocm         Specific conductance              NaN
# 1138        TempW_C           Temperature, water              NaN
# 2280  Depth_bott_ft                Depth, bottom              NaN
# 2281         DO_mgl        Dissolved oxygen (DO)              NaN
# 2282     DO_percent  Dissolved oxygen saturation              NaN
# 2283         Fe_ugl                         Iron  Total Recovrble
# ...

# %%
print("Parameters from 3/15/2016 12:00:00 AM")
data.loc[data['SampleDate'] == "3/15/2016 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 3/15/2016 12:00:00 AM
#            Parameter                                Characteristic  \
# 1139          TN_ugl                                      Nitrogen
# 1140        Turb_ntu                                     Turbidity
# 1141  Color_true_pcu                                    True Color
# 1142         TSS_mgl                  Total Suspended Solids (TSS)
# 1143         TOC_mgl                    Total Organic Carbon (TOC)
# 1144         TempW_C                            Temperature, water
# 1145         SO4_mgl                  Sulfur, sulfate (SO4) as SO4
# 1146     Cond_umhocm                          Specific conductance
# 1147          Na_mgl                                        Sodium
# 1148       Secchi_ft                             Secchi disk depth
# 1149           K_mgl                                     Potassium
# 1150          OP_mgl              Phosphorus, phosphate (PO4) as P
# ...

# %%
print("Parameters from 6/27/2016 12:00:00 AM")
data.loc[data['SampleDate'] == "6/27/2016 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 6/27/2016 12:00:00 AM
#            Parameter                                Characteristic  \
# 1174     CarbAlk_mgl                Alkalinity, Carbonate as CaCO3
# 1175          As_ugl                                       Arsenic
# 1176          Ca_mgl                                       Calcium
# 1177          Cl_mgl                                      Chloride
# 1178       ChlaC_ugl       Chlorophyll a, corrected for pheophytin
# 1179        Chla_ugl     Chlorophyll a, uncorrected for pheophytin
# 1180          Cr_ugl                                      Chromium
# 1181          Cu_ugl                                        Copper
# 1182   Depth_bott_ft                                 Depth, bottom
# 1183          DO_mgl                         Dissolved oxygen (DO)
# 1184      DO_percent                   Dissolved oxygen saturation
# 1185         TDS_mgl                              Dissolved Solids
# ...

# %%
print("Parameters from 9/20/2016 12:00:00 AM")
data.loc[data['SampleDate'] == "9/20/2016 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 9/20/2016 12:00:00 AM
#            Parameter                                Characteristic  \
# 1210         TempW_F                            Temperature, water
# 1211          TN_ugl                                      Nitrogen
# 1212     CarbAlk_mgl                Alkalinity, Carbonate as CaCO3
# 1213          As_ugl                                       Arsenic
# 1214          Ca_mgl                                       Calcium
# 1215          Cl_mgl                                      Chloride
# 1216       ChlaC_ugl       Chlorophyll a, corrected for pheophytin
# 1217        Chla_ugl     Chlorophyll a, uncorrected for pheophytin
# 1218          Cr_ugl                                      Chromium
# 1219          Cu_ugl                                        Copper
# 1220   Depth_bott_ft                                 Depth, bottom
# 1221          DO_mgl                         Dissolved oxygen (DO)
# ...

# %%
print("Parameters from 10/18/2016 12:00:00 AM")
data.loc[data['SampleDate'] == "10/18/2016 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 10/18/2016 12:00:00 AM
#            Parameter                                Characteristic  \
# 1247          TN_ugl                                      Nitrogen
# 1248     CarbAlk_mgl                Alkalinity, Carbonate as CaCO3
# 1249          As_ugl                                       Arsenic
# 1250          Ca_mgl                                       Calcium
# 1251          Cl_mgl                                      Chloride
# 1252       ChlaC_ugl       Chlorophyll a, corrected for pheophytin
# 1253        Chla_ugl     Chlorophyll a, uncorrected for pheophytin
# 1254          Cr_ugl                                      Chromium
# 1255          Cu_ugl                                        Copper
# 1256   Depth_bott_ft                                 Depth, bottom
# 1257          DO_mgl                         Dissolved oxygen (DO)
# 1258      DO_percent                   Dissolved oxygen saturation
# ...

# %%
print("Parameters from 12/14/2016 12:00:00 AM")
data.loc[data['SampleDate'] == "12/14/2016 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 12/14/2016 12:00:00 AM
#            Parameter                                Characteristic  \
# 1283     CarbAlk_mgl                Alkalinity, Carbonate as CaCO3
# 1284          As_ugl                                       Arsenic
# 1285          Ca_mgl                                       Calcium
# 1286          Cl_mgl                                      Chloride
# 1287       ChlaC_ugl       Chlorophyll a, corrected for pheophytin
# 1288        Chla_ugl     Chlorophyll a, uncorrected for pheophytin
# 1289          Cr_ugl                                      Chromium
# 1290   Depth_bott_ft                                 Depth, bottom
# 1291          DO_mgl                         Dissolved oxygen (DO)
# 1292      DO_percent                   Dissolved oxygen saturation
# 1293         TDS_mgl                              Dissolved Solids
# 1294           F_mgl                                     Fluorides
# ...

# %%
print("Parameters from 07-12-2017 0:00")
data.loc[data['SampleDate'] == "07-12-2017 0:00", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 07-12-2017 0:00
#            Parameter                                Characteristic  \
# 1318          TN_ugl                                      Nitrogen
# 1319     CarbAlk_mgl                Alkalinity, Carbonate as CaCO3
# 1320          As_ugl                                       Arsenic
# 1321          Ca_mgl                                       Calcium
# 1322          Cl_mgl                                      Chloride
# 1323       ChlaC_ugl       Chlorophyll a, corrected for pheophytin
# 1324        Chla_ugl     Chlorophyll a, uncorrected for pheophytin
# 1325          Cu_ugl                                        Copper
# 1326   Depth_bott_ft                                 Depth, bottom
# 1327          DO_mgl                         Dissolved oxygen (DO)
# 1328      DO_percent                   Dissolved oxygen saturation
# 1329         TDS_mgl                              Dissolved Solids
# ...

# %%
print("Parameters from 01-11-1978 0:00")
data.loc[data['SampleDate'] == "01-11-1978 0:00", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 01-11-1978 0:00
#                   Parameter  \
# 1353                 TN_ugl
# 1354          Alk_CaCO3_mgl
# 1355            Ca_diss_mgl
# 1356            Cl_diss_mgl
# 1357               Chla_ugl
# 1358            Cu_diss_ugl
# 1359                 DO_mgl
# 1360  Hardnesscarbonate_mgl
# 1361            Fe_diss_ugl
# 1362                 Fe_ugl
# 1363            Mg_diss_mgl
# 1364            Mn_diss_ugl
# 1365         NH3_N_diss_ugl
# 1366                TKN_ugl
# 1367           NO3_diss_ugl
# 1368                NOx_ugl
# 1369                     pH
# 1370               Pheo_ugl
# 1371                 TP_ugl
# 1372                 TP_ugl
# 1373                  K_mgl
# 1374                 Si_ugl
# 1375            Na_diss_mgl
# 1376            Cond_umhocm
# 1377           SO4_diss_mgl
# 1378                TempW_C
# 1379         Color_true_pcu
# 1380                TempW_F
#
#                                          Characteristic Sample_Fraction  \
# ...

# %%
print("Parameters from 1/20/1978 12:00:00 AM")
data.loc[data['SampleDate'] == "1/20/1978 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 1/20/1978 12:00:00 AM
#                   Parameter  \
# 1381          Alk_CaCO3_mgl
# 1382            Ca_diss_mgl
# 1383            Cl_diss_mgl
# 1384            Cu_diss_ugl
# 1385  Hardnesscarbonate_mgl
# 1386                 Fe_ugl
# 1387            Mg_diss_mgl
# 1388         NH3_N_diss_ugl
# 1389                TKN_ugl
# 1390           NO3_diss_ugl
# 1391                NOx_ugl
# 1392           NO2_diss_ugl
# 1393                 TP_ugl
# 1394                 TP_ugl
# 1395                  K_mgl
# 1396                 Si_ugl
# 1397            Na_diss_mgl
# 1398           SO4_diss_mgl
# 1399         Color_true_pcu
# 1400                 TN_ugl
#
#                                          Characteristic Sample_Fraction  \
# 1381  Alkalinity, Total (total hydroxide+carbonate+b...           Total
# 1382                                            Calcium       Dissolved
# 1383                                           Chloride       Dissolved
# ...

# %%
print("Parameters from 02-08-1978 0:00")
data.loc[data['SampleDate'] == "02-08-1978 0:00", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 02-08-1978 0:00
#                   Parameter  \
# 1401                 TN_ugl
# 1402          Alk_CaCO3_mgl
# 1403            Ca_diss_mgl
# 1404            Cl_diss_mgl
# 1405               Chla_ugl
# 1406            Cu_diss_ugl
# 1407                 DO_mgl
# 1408  Hardnesscarbonate_mgl
# 1409            Fe_diss_ugl
# 1410                 Fe_ugl
# 1411            Mg_diss_mgl
# 1412            Mn_diss_ugl
# 1413         NH3_N_diss_ugl
# 1414                TKN_ugl
# 1415           NO3_diss_ugl
# 1416                NOx_ugl
# 1417                     pH
# 1418               Pheo_ugl
# 1419                 TP_ugl
# 1420                 TP_ugl
# 1421                 OP_mgl
# 1422                  K_mgl
# 1423                 Si_ugl
# 1424            Na_diss_mgl
# 1425            Cond_umhocm
# 1426           SO4_diss_mgl
# 1427                TempW_C
# 1428         Color_true_pcu
# 1429                TempW_F
#
# ...

# %%
print("Parameters from 03-08-1978 0:00")
data.loc[data['SampleDate'] == "03-08-1978 0:00", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 03-08-1978 0:00
#                   Parameter  \
# 1430                TempW_F
# 1431          Alk_CaCO3_mgl
# 1432            Ca_diss_mgl
# 1433            Cl_diss_mgl
# 1434               Chla_ugl
# 1435            Cu_diss_ugl
# 1436                 DO_mgl
# 1437  Hardnesscarbonate_mgl
# 1438                 Fe_ugl
# 1439            Mg_diss_mgl
# 1440            Mn_diss_ugl
# 1441         NH3_N_diss_ugl
# 1442                TKN_ugl
# 1443                NOx_ugl
# 1444                     pH
# 1445               Pheo_ugl
# 1446                 TP_ugl
# 1447                 TP_ugl
# 1448                  K_mgl
# 1449                 Si_ugl
# 1450            Na_diss_mgl
# 1451            Cond_umhocm
# 1452           SO4_diss_mgl
# 1453                TempW_C
# 1454         Color_true_pcu
# 1455                 TN_ugl
#
#                                          Characteristic Sample_Fraction  \
# 1430                                 Temperature, water             NaN
# ...

# %%
print("Parameters from 04-04-1978 0:00")
data.loc[data['SampleDate'] == "04-04-1978 0:00", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 04-04-1978 0:00
#      Parameter                             Characteristic Sample_Fraction  \
# 1456  Chla_ugl  Chlorophyll a, uncorrected for pheophytin           Total
# 1457  Pheo_ugl                               Pheophytin-a           Total
#
#       Result_Value Result_Unit
# 1456           4.2        ug/l
# 1457           2.8        ug/l

# %%
print("Parameters from 04-05-1978 0:00")
data.loc[data['SampleDate'] == "04-05-1978 0:00", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 04-05-1978 0:00
#                   Parameter  \
# 1458          Alk_CaCO3_mgl
# 1459            Ca_diss_mgl
# 1460            Cl_diss_mgl
# 1461                 DO_mgl
# 1462  Hardnesscarbonate_mgl
# 1463            Fe_diss_ugl
# 1464                 Fe_ugl
# 1465            Mg_diss_mgl
# 1466            Mn_diss_ugl
# 1467         NH3_N_diss_ugl
# 1468                TKN_ugl
# 1469                     pH
# 1470                 TP_ugl
# 1471                 TP_ugl
# 1472                  K_mgl
# 1473                 Si_ugl
# 1474            Na_diss_mgl
# 1475            Cond_umhocm
# 1476           SO4_diss_mgl
# 1477         Color_true_pcu
#
#                                          Characteristic Sample_Fraction  \
# 1458  Alkalinity, Total (total hydroxide+carbonate+b...           Total
# 1459                                            Calcium       Dissolved
# 1460                                           Chloride       Dissolved
# ...

# %%
print("Parameters from 4/19/1978 12:00:00 AM")
data.loc[data['SampleDate'] == "4/19/1978 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 4/19/1978 12:00:00 AM
#                   Parameter  \
# 1478          Alk_CaCO3_mgl
# 1479            Ca_diss_mgl
# 1480            Cl_diss_mgl
# 1481               Chla_ugl
# 1482                 DO_mgl
# 1483  Hardnesscarbonate_mgl
# 1484            Fe_diss_ugl
# 1485                 Fe_ugl
# 1486            Mg_diss_mgl
# 1487            Mn_diss_ugl
# 1488                TKN_ugl
# 1489               Pheo_ugl
# 1490                 TP_ugl
# 1491                 TP_ugl
# 1492                  K_mgl
# 1493                 Si_ugl
# 1494            Na_diss_mgl
# 1495            Cond_umhocm
# 1496           SO4_diss_mgl
# 1497                TempW_C
# 1498         Color_true_pcu
# 1499                TempW_F
#
#                                          Characteristic Sample_Fraction  \
# 1478  Alkalinity, Total (total hydroxide+carbonate+b...           Total
# 1479                                            Calcium       Dissolved
# ...

# %%
print("Parameters from 05-03-1978 0:00")
data.loc[data['SampleDate'] == "05-03-1978 0:00", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 05-03-1978 0:00
#                   Parameter  \
# 1500                TempW_F
# 1501          Alk_CaCO3_mgl
# 1502            Ca_diss_mgl
# 1503            Cl_diss_mgl
# 1504               Chla_ugl
# 1505            Cu_diss_ugl
# 1506                 DO_mgl
# 1507  Hardnesscarbonate_mgl
# 1508            Fe_diss_ugl
# 1509                 Fe_ugl
# 1510            Mg_diss_mgl
# 1511            Mn_diss_ugl
# 1512         NH3_N_diss_ugl
# 1513                TKN_ugl
# 1514                     pH
# 1515               Pheo_ugl
# 1516                 TP_ugl
# 1517                 TP_ugl
# 1518                  K_mgl
# 1519                 Si_ugl
# 1520            Na_diss_mgl
# 1521            Cond_umhocm
# 1522           SO4_diss_mgl
# 1523                TempW_C
# 1524         Color_true_pcu
#
#                                          Characteristic Sample_Fraction  \
# 1500                                 Temperature, water             NaN
# ...

# %%
print("Parameters from 5/17/1978 12:00:00 AM")
data.loc[data['SampleDate'] == "5/17/1978 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 5/17/1978 12:00:00 AM
#                   Parameter  \
# 1525          Alk_CaCO3_mgl
# 1526            Ca_diss_mgl
# 1527            Cl_diss_mgl
# 1528               Chla_ugl
# 1529            Cu_diss_ugl
# 1530                 DO_mgl
# 1531  Hardnesscarbonate_mgl
# 1532            Fe_diss_ugl
# 1533                 Fe_ugl
# 1534            Mg_diss_mgl
# 1535            Mn_diss_ugl
# 1536         NH3_N_diss_ugl
# 1537                TKN_ugl
# 1538                     pH
# 1539               Pheo_ugl
# 1540                 TP_ugl
# 1541                 TP_ugl
# 1542                  K_mgl
# 1543                 Si_ugl
# 1544            Na_diss_mgl
# 1545            Cond_umhocm
# 1546           SO4_diss_mgl
# 1547                TempW_C
# 1548         Color_true_pcu
# 1549                TempW_F
#
#                                          Characteristic Sample_Fraction  \
# 1525  Alkalinity, Total (total hydroxide+carbonate+b...           Total
# ...

# %%
print("Parameters from 5/31/1978 12:00:00 AM")
data.loc[data['SampleDate'] == "5/31/1978 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 5/31/1978 12:00:00 AM
#      Parameter                             Characteristic Sample_Fraction  \
# 1550  Chla_ugl  Chlorophyll a, uncorrected for pheophytin           Total
# 1551  Pheo_ugl                               Pheophytin-a           Total
#
#       Result_Value Result_Unit
# 1550           2.1        ug/l
# 1551           1.1        ug/l

# %%
print("Parameters from 06-08-1978 0:00")
data.loc[data['SampleDate'] == "06-08-1978 0:00", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 06-08-1978 0:00
#                   Parameter  \
# 1552          Alk_CaCO3_mgl
# 1553            Ca_diss_mgl
# 1554            Cl_diss_mgl
# 1555               Chla_ugl
# 1556            Cu_diss_ugl
# 1557                 DO_mgl
# 1558  Hardnesscarbonate_mgl
# 1559            Fe_diss_ugl
# 1560                 Fe_ugl
# 1561            Mg_diss_mgl
# 1562            Mn_diss_ugl
# 1563         NH3_N_diss_ugl
# 1564                TKN_ugl
# 1565                     pH
# 1566               Pheo_ugl
# 1567                 TP_ugl
# 1568                 TP_ugl
# 1569                  K_mgl
# 1570                 Si_ugl
# 1571            Na_diss_mgl
# 1572            Cond_umhocm
# 1573           SO4_diss_mgl
# 1574                TempW_C
# 1575         Color_true_pcu
# 1576                 Zn_ugl
# 1577                TempW_F
#
#                                          Characteristic Sample_Fraction  \
# 1552  Alkalinity, Total (total hydroxide+carbonate+b...           Total
# ...

# %%
print("Parameters from 07-11-1978 0:00")
data.loc[data['SampleDate'] == "07-11-1978 0:00", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 07-11-1978 0:00
#      Parameter                             Characteristic Sample_Fraction  \
# 1578  Chla_ugl  Chlorophyll a, uncorrected for pheophytin           Total
# 1579  Pheo_ugl                               Pheophytin-a           Total
#
#       Result_Value Result_Unit
# 1578           7.1        ug/l
# 1579           1.3        ug/l

# %%
print("Parameters from 07-12-1978 0:00")
data.loc[data['SampleDate'] == "07-12-1978 0:00", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 07-12-1978 0:00
#                   Parameter  \
# 1580          Alk_CaCO3_mgl
# 1581            Ca_diss_mgl
# 1582            Cl_diss_mgl
# 1583            Cu_diss_ugl
# 1584                 DO_mgl
# 1585  Hardnesscarbonate_mgl
# 1586            Fe_diss_ugl
# 1587                 Fe_ugl
# 1588            Mg_diss_mgl
# 1589            Mn_diss_ugl
# 1590                TKN_ugl
# 1591                     pH
# 1592                 TP_ugl
# 1593                 TP_ugl
# 1594                  K_mgl
# 1595                 Si_ugl
# 1596            Na_diss_mgl
# 1597            Cond_umhocm
# 1598           SO4_diss_mgl
# 1599                TempW_C
# 1600         Color_true_pcu
# 1601                TempW_F
#
#                                          Characteristic Sample_Fraction  \
# 1580  Alkalinity, Total (total hydroxide+carbonate+b...           Total
# 1581                                            Calcium       Dissolved
# ...

# %%
print("Parameters from 08-09-1978 0:00")
data.loc[data['SampleDate'] == "08-09-1978 0:00", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 08-09-1978 0:00
#                   Parameter  \
# 1602          Alk_CaCO3_mgl
# 1603            Ca_diss_mgl
# 1604            Cl_diss_mgl
# 1605               Chla_ugl
# 1606            Cu_diss_ugl
# 1607                 DO_mgl
# 1608  Hardnesscarbonate_mgl
# 1609            Fe_diss_ugl
# 1610                 Fe_ugl
# 1611            Mg_diss_mgl
# 1612            Mn_diss_ugl
# 1613                TKN_ugl
# 1614                NOx_ugl
# 1615                     pH
# 1616               Pheo_ugl
# 1617                 TP_ugl
# 1618                 TP_ugl
# 1619                 OP_mgl
# 1620                  K_mgl
# 1621                 Si_ugl
# 1622            Na_diss_mgl
# 1623            Cond_umhocm
# 1624           SO4_diss_mgl
# 1625                TempW_C
# 1626         Color_true_pcu
# 1627                TempW_F
# 1628                 TN_ugl
#
#                                          Characteristic Sample_Fraction  \
# ...

# %%
print("Parameters from 9/13/1978 12:00:00 AM")
data.loc[data['SampleDate'] == "9/13/1978 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 9/13/1978 12:00:00 AM
#                   Parameter  \
# 1629                 TN_ugl
# 1630          Alk_CaCO3_mgl
# 1631            Ca_diss_mgl
# 1632            Cl_diss_mgl
# 1633               Chla_ugl
# 1634            Cu_diss_ugl
# 1635                 DO_mgl
# 1636  Hardnesscarbonate_mgl
# 1637            Fe_diss_ugl
# 1638                 Fe_ugl
# 1639            Mg_diss_mgl
# 1640            Mn_diss_ugl
# 1641                TKN_ugl
# 1642                NOx_ugl
# 1643                     pH
# 1644               Pheo_ugl
# 1645                 TP_ugl
# 1646                 TP_ugl
# 1647                 OP_mgl
# 1648                  K_mgl
# 1649                 Si_ugl
# 1650            Na_diss_mgl
# 1651            Cond_umhocm
# 1652           SO4_diss_mgl
# 1653                TempW_C
# 1654         Color_true_pcu
# 1655                TempW_F
#
#                                          Characteristic Sample_Fraction  \
# ...

# %%
print("Parameters from 10/17/1978 12:00:00 AM")
data.loc[data['SampleDate'] == "10/17/1978 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 10/17/1978 12:00:00 AM
#                   Parameter  \
# 1656                TempW_F
# 1657                 TN_ugl
# 1658          Alk_CaCO3_mgl
# 1659            Ca_diss_mgl
# 1660            Cl_diss_mgl
# 1661               Chla_ugl
# 1662            Cu_diss_ugl
# 1663                 DO_mgl
# 1664  Hardnesscarbonate_mgl
# 1665            Fe_diss_ugl
# 1666                 Fe_ugl
# 1667            Mg_diss_mgl
# 1668            Mn_diss_ugl
# 1669         NH3_N_diss_ugl
# 1670                TKN_ugl
# 1671                NOx_ugl
# 1672                     pH
# 1673               Pheo_ugl
# 1674                 TP_ugl
# 1675                 TP_ugl
# 1676                  K_mgl
# 1677                 Si_ugl
# 1678            Na_diss_mgl
# 1679            Cond_umhocm
# 1680           SO4_diss_mgl
# 1681                TempW_C
# 1682         Color_true_pcu
#
#                                          Characteristic Sample_Fraction  \
# ...

# %%
print("Parameters from 11-06-1978 0:00")
data.loc[data['SampleDate'] == "11-06-1978 0:00", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 11-06-1978 0:00
#                   Parameter  \
# 1683          Alk_CaCO3_mgl
# 1684            Ca_diss_mgl
# 1685            Cl_diss_mgl
# 1686               Chla_ugl
# 1687            Cu_diss_ugl
# 1688                 DO_mgl
# 1689  Hardnesscarbonate_mgl
# 1690            Fe_diss_ugl
# 1691                 Fe_ugl
# 1692            Mg_diss_mgl
# 1693            Mn_diss_ugl
# 1694                TKN_ugl
# 1695                     pH
# 1696               Pheo_ugl
# 1697                 TP_ugl
# 1698                 TP_ugl
# 1699                 OP_mgl
# 1700                  K_mgl
# 1701                 Si_ugl
# 1702            Na_diss_mgl
# 1703            Cond_umhocm
# 1704           SO4_diss_mgl
# 1705                TempW_C
# 1706         Color_true_pcu
# 1707                 Zn_ugl
# 1708                TempW_F
#
#                                          Characteristic Sample_Fraction  \
# 1683  Alkalinity, Total (total hydroxide+carbonate+b...           Total
# ...

# %%
print("Parameters from 12/13/1978 12:00:00 AM")
data.loc[data['SampleDate'] == "12/13/1978 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 12/13/1978 12:00:00 AM
#                   Parameter  \
# 1709                TempW_F
# 1710                 TN_ugl
# 1711          Alk_CaCO3_mgl
# 1712            Ca_diss_mgl
# 1713            Cl_diss_mgl
# 1714               Chla_ugl
# 1715            Cu_diss_ugl
# 1716                 DO_mgl
# 1717  Hardnesscarbonate_mgl
# 1718            Fe_diss_ugl
# 1719                 Fe_ugl
# 1720            Mg_diss_mgl
# 1721            Mn_diss_ugl
# 1722         NH3_N_diss_ugl
# 1723                TKN_ugl
# 1724           NO3_diss_ugl
# 1725                NOx_ugl
# 1726                     pH
# 1727               Pheo_ugl
# 1728                 TP_ugl
# 1729                 TP_ugl
# 1730                 OP_mgl
# 1731                  K_mgl
# 1732                 Si_ugl
# 1733            Na_diss_mgl
# 1734            Cond_umhocm
# 1735           SO4_diss_mgl
# 1736                TempW_C
# 1737         Color_true_pcu
#
# ...

# %%
print("Parameters from 1/15/1979 12:00:00 AM")
data.loc[data['SampleDate'] == "1/15/1979 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 1/15/1979 12:00:00 AM
#                   Parameter                                Characteristic  \
# 1738                 TN_ugl                                      Nitrogen
# 1739                TempW_F                            Temperature, water
# 1740            Ca_diss_mgl                                       Calcium
# 1741            Cl_diss_mgl                                      Chloride
# 1742                 DO_mgl                         Dissolved oxygen (DO)
# 1743                  F_mgl                                     Fluorides
# 1744  Hardnesscarbonate_mgl                           Hardness, carbonate
# 1745                 Fe_ugl                                          Iron
# 1746            Mg_diss_mgl                                     Magnesium
# 1747         NH3_N_diss_ugl                        Nitrogen, ammonia as N
# 1748                TKN_ugl                            Nitrogen, Kjeldahl
# ...

# %%
print("Parameters from 02-12-1979 0:00")
data.loc[data['SampleDate'] == "02-12-1979 0:00", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 02-12-1979 0:00
#                   Parameter                    Characteristic Sample_Fraction  \
# 1761            Ca_diss_mgl                           Calcium       Dissolved
# 1762            Cl_diss_mgl                          Chloride       Dissolved
# 1763                 DO_mgl             Dissolved oxygen (DO)           Total
# 1764  Hardnesscarbonate_mgl               Hardness, carbonate           Total
# 1765                 Fe_ugl                              Iron           Total
# 1766            Mg_diss_mgl                         Magnesium       Dissolved
# 1767         NH3_N_diss_ugl            Nitrogen, ammonia as N       Dissolved
# 1768                TKN_ugl                Nitrogen, Kjeldahl           Total
# 1769                     pH                                pH           Total
# 1770                 TP_ugl                   Phosphorus as P       Dissolved
# 1771                 TP_ugl                   Phosphorus as P           Total
# ...

# %%
print("Parameters from 03-12-1979 0:00")
data.loc[data['SampleDate'] == "03-12-1979 0:00", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 03-12-1979 0:00
#                   Parameter                    Characteristic Sample_Fraction  \
# 1779                TempW_F                Temperature, water             NaN
# 1780            Ca_diss_mgl                           Calcium       Dissolved
# 1781            Cl_diss_mgl                          Chloride       Dissolved
# 1782                 DO_mgl             Dissolved oxygen (DO)           Total
# 1783                  F_mgl                         Fluorides           Total
# 1784  Hardnesscarbonate_mgl               Hardness, carbonate           Total
# 1785                 Fe_ugl                              Iron           Total
# 1786            Mg_diss_mgl                         Magnesium       Dissolved
# 1787         NH3_N_diss_ugl            Nitrogen, ammonia as N       Dissolved
# 1788                TKN_ugl                Nitrogen, Kjeldahl           Total
# 1789                     pH                                pH           Total
# ...

# %%
print("Parameters from 04-02-1979 0:00")
data.loc[data['SampleDate'] == "04-02-1979 0:00", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 04-02-1979 0:00
#                   Parameter                    Characteristic Sample_Fraction  \
# 1798            Ca_diss_mgl                           Calcium       Dissolved
# 1799            Cl_diss_mgl                          Chloride       Dissolved
# 1800                 DO_mgl             Dissolved oxygen (DO)           Total
# 1801                  F_mgl                         Fluorides           Total
# 1802  Hardnesscarbonate_mgl               Hardness, carbonate           Total
# 1803                 Fe_ugl                              Iron           Total
# 1804            Mg_diss_mgl                         Magnesium       Dissolved
# 1805         NH3_N_diss_ugl            Nitrogen, ammonia as N       Dissolved
# 1806                TKN_ugl                Nitrogen, Kjeldahl           Total
# 1807                     pH                                pH           Total
# 1808                 TP_ugl                   Phosphorus as P       Dissolved
# ...

# %%
print("Parameters from 4/16/1979 12:00:00 AM")
data.loc[data['SampleDate'] == "4/16/1979 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 4/16/1979 12:00:00 AM
#                   Parameter                    Characteristic Sample_Fraction  \
# 1817                TempW_F                Temperature, water             NaN
# 1818            Ca_diss_mgl                           Calcium       Dissolved
# 1819            Cl_diss_mgl                          Chloride       Dissolved
# 1820                 DO_mgl             Dissolved oxygen (DO)           Total
# 1821                  F_mgl                         Fluorides           Total
# 1822  Hardnesscarbonate_mgl               Hardness, carbonate           Total
# 1823                 Fe_ugl                              Iron           Total
# 1824            Mg_diss_mgl                         Magnesium       Dissolved
# 1825                     pH                                pH           Total
# 1826                 TP_ugl                   Phosphorus as P       Dissolved
# ...

# %%
print("Parameters from 05-01-1979 0:00")
data.loc[data['SampleDate'] == "05-01-1979 0:00", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 05-01-1979 0:00
#                   Parameter                                Characteristic  \
# 1834            Ca_diss_mgl                                       Calcium
# 1835            Cl_diss_mgl                                      Chloride
# 1836                 DO_mgl                         Dissolved oxygen (DO)
# 1837                  F_mgl                                     Fluorides
# 1838  Hardnesscarbonate_mgl                           Hardness, carbonate
# 1839                 Fe_ugl                                          Iron
# 1840            Mg_diss_mgl                                     Magnesium
# 1841         NH3_N_diss_ugl                        Nitrogen, ammonia as N
# 1842                TKN_ugl                            Nitrogen, Kjeldahl
# 1843           NO3_diss_ugl                  Nitrogen, Nitrate (NO3) as N
# 1844                NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N
# ...

# %%
print("Parameters from 5/14/1979 12:00:00 AM")
data.loc[data['SampleDate'] == "5/14/1979 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 5/14/1979 12:00:00 AM
#                   Parameter                                Characteristic  \
# 1856                 TN_ugl                                      Nitrogen
# 1857                TempW_F                            Temperature, water
# 1858            Ca_diss_mgl                                       Calcium
# 1859            Cl_diss_mgl                                      Chloride
# 1860                 DO_mgl                         Dissolved oxygen (DO)
# 1861                  F_mgl                                     Fluorides
# 1862  Hardnesscarbonate_mgl                           Hardness, carbonate
# 1863                 Fe_ugl                                          Iron
# 1864            Mg_diss_mgl                                     Magnesium
# 1865         NH3_N_diss_ugl                        Nitrogen, ammonia as N
# 1866                TKN_ugl                            Nitrogen, Kjeldahl
# ...

# %%
print("Parameters from 5/31/1979 12:00:00 AM")
data.loc[data['SampleDate'] == "5/31/1979 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 5/31/1979 12:00:00 AM
#                   Parameter                    Characteristic Sample_Fraction  \
# 1877            Ca_diss_mgl                           Calcium       Dissolved
# 1878            Cl_diss_mgl                          Chloride       Dissolved
# 1879                 DO_mgl             Dissolved oxygen (DO)           Total
# 1880                  F_mgl                         Fluorides           Total
# 1881  Hardnesscarbonate_mgl               Hardness, carbonate           Total
# 1882                 Fe_ugl                              Iron           Total
# 1883            Mg_diss_mgl                         Magnesium       Dissolved
# 1884                TKN_ugl                Nitrogen, Kjeldahl           Total
# 1885                     pH                                pH           Total
# 1886                 TP_ugl                   Phosphorus as P       Dissolved
# ...

# %%
print("Parameters from 06-11-1979 0:00")
data.loc[data['SampleDate'] == "06-11-1979 0:00", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 06-11-1979 0:00
#                   Parameter          Characteristic Sample_Fraction  \
# 1895                TempW_F      Temperature, water             NaN
# 1896            Ca_diss_mgl                 Calcium       Dissolved
# 1897            Cl_diss_mgl                Chloride       Dissolved
# 1898                 DO_mgl   Dissolved oxygen (DO)           Total
# 1899                  F_mgl               Fluorides           Total
# 1900  Hardnesscarbonate_mgl     Hardness, carbonate           Total
# 1901                 Fe_ugl                    Iron           Total
# 1902            Mg_diss_mgl               Magnesium       Dissolved
# 1903         NH3_N_diss_ugl  Nitrogen, ammonia as N       Dissolved
# 1904                TKN_ugl      Nitrogen, Kjeldahl           Total
# 1905                     pH                      pH           Total
# 1906                 TP_ugl         Phosphorus as P       Dissolved
# ...

# %%
print("Parameters from 6/25/1979 12:00:00 AM")
data.loc[data['SampleDate'] == "6/25/1979 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 6/25/1979 12:00:00 AM
#                   Parameter                    Characteristic Sample_Fraction  \
# 1913            Ca_diss_mgl                           Calcium       Dissolved
# 1914            Cl_diss_mgl                          Chloride       Dissolved
# 1915                 DO_mgl             Dissolved oxygen (DO)           Total
# 1916                  F_mgl                         Fluorides           Total
# 1917  Hardnesscarbonate_mgl               Hardness, carbonate           Total
# 1918                 Fe_ugl                              Iron           Total
# 1919            Mg_diss_mgl                         Magnesium       Dissolved
# 1920         NH3_N_diss_ugl            Nitrogen, ammonia as N       Dissolved
# 1921                TKN_ugl                Nitrogen, Kjeldahl           Total
# 1922                     pH                                pH           Total
# ...

# %%
print("Parameters from 07-09-1979 0:00")
data.loc[data['SampleDate'] == "07-09-1979 0:00", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 07-09-1979 0:00
#                   Parameter                    Characteristic Sample_Fraction  \
# 1932                TempW_F                Temperature, water             NaN
# 1933            Ca_diss_mgl                           Calcium       Dissolved
# 1934            Cl_diss_mgl                          Chloride       Dissolved
# 1935                 DO_mgl             Dissolved oxygen (DO)           Total
# 1936                  F_mgl                         Fluorides           Total
# 1937  Hardnesscarbonate_mgl               Hardness, carbonate           Total
# 1938                 Fe_ugl                              Iron           Total
# 1939            Mg_diss_mgl                         Magnesium       Dissolved
# 1940                TKN_ugl                Nitrogen, Kjeldahl           Total
# 1941                     pH                                pH           Total
# 1942                 TP_ugl                   Phosphorus as P       Dissolved
# ...

# %%
print("Parameters from 7/23/1979 12:00:00 AM")
data.loc[data['SampleDate'] == "7/23/1979 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 7/23/1979 12:00:00 AM
#                   Parameter         Characteristic Sample_Fraction  \
# 1950            Ca_diss_mgl                Calcium       Dissolved
# 1951            Cl_diss_mgl               Chloride       Dissolved
# 1952                 DO_mgl  Dissolved oxygen (DO)           Total
# 1953                  F_mgl              Fluorides           Total
# 1954  Hardnesscarbonate_mgl    Hardness, carbonate           Total
# 1955                 Fe_ugl                   Iron           Total
# 1956            Mg_diss_mgl              Magnesium       Dissolved
# 1957                TKN_ugl     Nitrogen, Kjeldahl           Total
# 1958                     pH                     pH           Total
# 1959                 TP_ugl        Phosphorus as P       Dissolved
# 1960                 TP_ugl        Phosphorus as P           Total
# 1961                  K_mgl              Potassium       Dissolved
# ...

# %%
print("Parameters from 8/13/1979 12:00:00 AM")
data.loc[data['SampleDate'] == "8/13/1979 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 8/13/1979 12:00:00 AM
#                   Parameter                                Characteristic  \
# 1967                TempW_F                            Temperature, water
# 1968            Ca_diss_mgl                                       Calcium
# 1969            Cl_diss_mgl                                      Chloride
# 1970                 DO_mgl                         Dissolved oxygen (DO)
# 1971                  F_mgl                                     Fluorides
# 1972  Hardnesscarbonate_mgl                           Hardness, carbonate
# 1973                 Fe_ugl                                          Iron
# 1974            Mg_diss_mgl                                     Magnesium
# 1975         NH3_N_diss_ugl                        Nitrogen, ammonia as N
# 1976                TKN_ugl                            Nitrogen, Kjeldahl
# 1977           NO3_diss_ugl                  Nitrogen, Nitrate (NO3) as N
# ...

# %%
print("Parameters from 09-10-1979 0:00")
data.loc[data['SampleDate'] == "09-10-1979 0:00", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 09-10-1979 0:00
#                   Parameter                                Characteristic  \
# 1989                 TN_ugl                                      Nitrogen
# 1990            Ca_diss_mgl                                       Calcium
# 1991            Cl_diss_mgl                                      Chloride
# 1992                 DO_mgl                         Dissolved oxygen (DO)
# 1993                  F_mgl                                     Fluorides
# 1994  Hardnesscarbonate_mgl                           Hardness, carbonate
# 1995                 Fe_ugl                                          Iron
# 1996            Mg_diss_mgl                                     Magnesium
# 1997         NH3_N_diss_ugl                        Nitrogen, ammonia as N
# 1998                TKN_ugl                            Nitrogen, Kjeldahl
# 1999           NO3_diss_ugl                  Nitrogen, Nitrate (NO3) as N
# ...

# %%
print("Parameters from 10/16/1979 12:00:00 AM")
data.loc[data['SampleDate'] == "10/16/1979 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 10/16/1979 12:00:00 AM
#                   Parameter                                Characteristic  \
# 2012            Ca_diss_mgl                                       Calcium
# 2013            Cl_diss_mgl                                      Chloride
# 2014                 DO_mgl                         Dissolved oxygen (DO)
# 2015                  F_mgl                                     Fluorides
# 2016  Hardnesscarbonate_mgl                           Hardness, carbonate
# 2017                 Fe_ugl                                          Iron
# 2018            Mg_diss_mgl                                     Magnesium
# 2019         NH3_N_diss_ugl                        Nitrogen, ammonia as N
# 2020                TKN_ugl                            Nitrogen, Kjeldahl
# 2021           NO3_diss_ugl                  Nitrogen, Nitrate (NO3) as N
# 2022                NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N
# ...

# %%
print("Parameters from 11-06-1979 0:00")
data.loc[data['SampleDate'] == "11-06-1979 0:00", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 11-06-1979 0:00
#                   Parameter                                Characteristic  \
# 2033                 TN_ugl                                      Nitrogen
# 2034            Ca_diss_mgl                                       Calcium
# 2035            Cl_diss_mgl                                      Chloride
# 2036                 DO_mgl                         Dissolved oxygen (DO)
# 2037                  F_mgl                                     Fluorides
# 2038  Hardnesscarbonate_mgl                           Hardness, carbonate
# 2039                 Fe_ugl                                          Iron
# 2040                TKN_ugl                            Nitrogen, Kjeldahl
# 2041           NO3_diss_ugl                  Nitrogen, Nitrate (NO3) as N
# 2042                NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N
# 2043           NO2_diss_ugl                  Nitrogen, Nitrite (NO2) as N
# ...

# %%
print("Parameters from 12-03-1979 0:00")
data.loc[data['SampleDate'] == "12-03-1979 0:00", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 12-03-1979 0:00
#                   Parameter                                Characteristic  \
# 2054                TempW_F                            Temperature, water
# 2055                 TN_ugl                                      Nitrogen
# 2056            Ca_diss_mgl                                       Calcium
# 2057            Cl_diss_mgl                                      Chloride
# 2058                 DO_mgl                         Dissolved oxygen (DO)
# 2059                  F_mgl                                     Fluorides
# 2060  Hardnesscarbonate_mgl                           Hardness, carbonate
# 2061                 Fe_ugl                                          Iron
# 2062            Mg_diss_mgl                                     Magnesium
# 2063         NH3_N_diss_ugl                        Nitrogen, ammonia as N
# 2064                TKN_ugl                            Nitrogen, Kjeldahl
# ...

# %%
print("Parameters from 1/15/1980 12:00:00 AM")
data.loc[data['SampleDate'] == "1/15/1980 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 1/15/1980 12:00:00 AM
#            Parameter                    Characteristic Sample_Fraction  \
# 2076     Cl_diss_mgl                          Chloride       Dissolved
# 2077          DO_mgl             Dissolved oxygen (DO)           Total
# 2078           F_mgl                         Fluorides           Total
# 2079          Fe_ugl                              Iron           Total
# 2080  NH3_N_diss_ugl            Nitrogen, ammonia as N       Dissolved
# 2081         TKN_ugl                Nitrogen, Kjeldahl           Total
# 2082              pH                                pH           Total
# 2083          TP_ugl                   Phosphorus as P           Total
# 2084          OP_mgl  Phosphorus, phosphate (PO4) as P           Total
# 2085     Cond_umhocm              Specific conductance           Total
# 2086         TempW_C                Temperature, water           Total
# 2087         TempW_F                Temperature, water             NaN
#
# ...

# %%
print("Parameters from 1/15/1980 12:00:00 AM")
data.loc[data['SampleDate'] == "1/15/1980 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 1/15/1980 12:00:00 AM
#            Parameter                    Characteristic Sample_Fraction  \
# 2076     Cl_diss_mgl                          Chloride       Dissolved
# 2077          DO_mgl             Dissolved oxygen (DO)           Total
# 2078           F_mgl                         Fluorides           Total
# 2079          Fe_ugl                              Iron           Total
# 2080  NH3_N_diss_ugl            Nitrogen, ammonia as N       Dissolved
# 2081         TKN_ugl                Nitrogen, Kjeldahl           Total
# 2082              pH                                pH           Total
# 2083          TP_ugl                   Phosphorus as P           Total
# 2084          OP_mgl  Phosphorus, phosphate (PO4) as P           Total
# 2085     Cond_umhocm              Specific conductance           Total
# 2086         TempW_C                Temperature, water           Total
# 2087         TempW_F                Temperature, water             NaN
#
# ...

# %%
print("Parameters from 3/17/1980 12:00:00 AM")
data.loc[data['SampleDate'] == "3/17/1980 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 3/17/1980 12:00:00 AM
#            Parameter                    Characteristic Sample_Fraction  \
# 2103     Cl_diss_mgl                          Chloride       Dissolved
# 2104          DO_mgl             Dissolved oxygen (DO)           Total
# 2105           F_mgl                         Fluorides           Total
# 2106          Fe_ugl                              Iron           Total
# 2107  NH3_N_diss_ugl            Nitrogen, ammonia as N       Dissolved
# 2108         TKN_ugl                Nitrogen, Kjeldahl           Total
# 2109              pH                                pH           Total
# 2110          TP_ugl                   Phosphorus as P           Total
# 2111          OP_mgl  Phosphorus, phosphate (PO4) as P           Total
# 2112     Cond_umhocm              Specific conductance           Total
# 2113         TempW_C                Temperature, water           Total
# 2114  Color_true_pcu                        True Color           Total
# ...

# %%
print("Parameters from 4/15/1980 12:00:00 AM")
data.loc[data['SampleDate'] == "4/15/1980 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 4/15/1980 12:00:00 AM
#            Parameter                    Characteristic Sample_Fraction  \
# 2116     Cl_diss_mgl                          Chloride       Dissolved
# 2117          DO_mgl             Dissolved oxygen (DO)           Total
# 2118           F_mgl                         Fluorides           Total
# 2119          Fe_ugl                              Iron           Total
# 2120  NH3_N_diss_ugl            Nitrogen, ammonia as N       Dissolved
# 2121         TKN_ugl                Nitrogen, Kjeldahl           Total
# 2122              pH                                pH           Total
# 2123          TP_ugl                   Phosphorus as P           Total
# 2124          OP_mgl  Phosphorus, phosphate (PO4) as P           Total
# 2125     Cond_umhocm              Specific conductance           Total
# 2126         TempW_C                Temperature, water           Total
# 2127  Color_true_pcu                        True Color           Total
# ...

# %%
print("Parameters from 5/19/1980 12:00:00 AM")
data.loc[data['SampleDate'] == "5/19/1980 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 5/19/1980 12:00:00 AM
#            Parameter                    Characteristic Sample_Fraction  \
# 2129     Cl_diss_mgl                          Chloride       Dissolved
# 2130          DO_mgl             Dissolved oxygen (DO)           Total
# 2131           F_mgl                         Fluorides           Total
# 2132          Fe_ugl                              Iron           Total
# 2133  NH3_N_diss_ugl            Nitrogen, ammonia as N       Dissolved
# 2134         TKN_ugl                Nitrogen, Kjeldahl           Total
# 2135              pH                                pH           Total
# 2136          TP_ugl                   Phosphorus as P           Total
# 2137          OP_mgl  Phosphorus, phosphate (PO4) as P           Total
# 2138     Cond_umhocm              Specific conductance           Total
# 2139         TempW_C                Temperature, water           Total
# 2140  Color_true_pcu                        True Color           Total
# ...

# %%
print("Parameters from 06-09-1980 0:00")
data.loc[data['SampleDate'] == "06-09-1980 0:00", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 06-09-1980 0:00
#            Parameter                                Characteristic  \
# 2142         TempW_F                            Temperature, water
# 2143     Cl_diss_mgl                                      Chloride
# 2144          DO_mgl                         Dissolved oxygen (DO)
# 2145           F_mgl                                     Fluorides
# 2146          Fe_ugl                                          Iron
# 2147  NH3_N_diss_ugl                        Nitrogen, ammonia as N
# 2148         TKN_ugl                            Nitrogen, Kjeldahl
# 2149         NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N
# 2150              pH                                            pH
# 2151          TP_ugl                               Phosphorus as P
# 2152          OP_mgl              Phosphorus, phosphate (PO4) as P
# 2153     Cond_umhocm                          Specific conductance
# ...

# %%
print("Parameters from 7/15/1980 12:00:00 AM")
data.loc[data['SampleDate'] == "7/15/1980 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 7/15/1980 12:00:00 AM
#            Parameter                                Characteristic  \
# 2157          TN_ugl                                      Nitrogen
# 2158     Cl_diss_mgl                                      Chloride
# 2159          DO_mgl                         Dissolved oxygen (DO)
# 2160           F_mgl                                     Fluorides
# 2161          Fe_ugl                                          Iron
# 2162         TKN_ugl                            Nitrogen, Kjeldahl
# 2163         NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N
# 2164              pH                                            pH
# 2165          TP_ugl                               Phosphorus as P
# 2166     Cond_umhocm                          Specific conductance
# 2167         TempW_C                            Temperature, water
# 2168  Color_true_pcu                                    True Color
# ...

# %%
print("Parameters from 8/18/1980 12:00:00 AM")
data.loc[data['SampleDate'] == "8/18/1980 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 8/18/1980 12:00:00 AM
#            Parameter                                Characteristic  \
# 2170         TempW_F                            Temperature, water
# 2171     Cl_diss_mgl                                      Chloride
# 2172          DO_mgl                         Dissolved oxygen (DO)
# 2173           F_mgl                                     Fluorides
# 2174          Fe_ugl                                          Iron
# 2175    NO3_diss_ugl                  Nitrogen, Nitrate (NO3) as N
# 2176         NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N
# 2177    NO2_diss_ugl                  Nitrogen, Nitrite (NO2) as N
# 2178              pH                                            pH
# 2179          TP_ugl                               Phosphorus as P
# 2180          OP_mgl              Phosphorus, phosphate (PO4) as P
# 2181     Cond_umhocm                          Specific conductance
# ...

# %%
print("Parameters from 9/16/1980 12:00:00 AM")
data.loc[data['SampleDate'] == "9/16/1980 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 9/16/1980 12:00:00 AM
#            Parameter                                Characteristic  \
# 2184     Cl_diss_mgl                                      Chloride
# 2185          DO_mgl                         Dissolved oxygen (DO)
# 2186           F_mgl                                     Fluorides
# 2187          Fe_ugl                                          Iron
# 2188  NH3_N_diss_ugl                        Nitrogen, ammonia as N
# 2189         TKN_ugl                            Nitrogen, Kjeldahl
# 2190    NO3_diss_ugl                  Nitrogen, Nitrate (NO3) as N
# 2191         NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N
# 2192    NO2_diss_ugl                  Nitrogen, Nitrite (NO2) as N
# 2193              pH                                            pH
# 2194          TP_ugl                               Phosphorus as P
# 2195          OP_mgl              Phosphorus, phosphate (PO4) as P
# ...

# %%
print("Parameters from 10/13/1980 12:00:00 AM")
data.loc[data['SampleDate'] == "10/13/1980 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 10/13/1980 12:00:00 AM
#            Parameter                                Characteristic  \
# 2201         TempW_F                            Temperature, water
# 2202          TN_ugl                                      Nitrogen
# 2203     Cl_diss_mgl                                      Chloride
# 2204          DO_mgl                         Dissolved oxygen (DO)
# 2205           F_mgl                                     Fluorides
# 2206          Fe_ugl                                          Iron
# 2207         TKN_ugl                            Nitrogen, Kjeldahl
# 2208         NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N
# 2209              pH                                            pH
# 2210          TP_ugl                               Phosphorus as P
# 2211          OP_mgl              Phosphorus, phosphate (PO4) as P
# 2212     Cond_umhocm                          Specific conductance
# ...

# %%
print("Parameters from 11-10-1980 0:00")
data.loc[data['SampleDate'] == "11-10-1980 0:00", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 11-10-1980 0:00
#            Parameter                                Characteristic  \
# 2215          TN_ugl                                      Nitrogen
# 2216         TempW_F                            Temperature, water
# 2217     Cl_diss_mgl                                      Chloride
# 2218          DO_mgl                         Dissolved oxygen (DO)
# 2219           F_mgl                                     Fluorides
# 2220          Fe_ugl                                          Iron
# 2221         TKN_ugl                            Nitrogen, Kjeldahl
# 2222    NO3_diss_ugl                  Nitrogen, Nitrate (NO3) as N
# 2223         NOx_ugl  Nitrogen, Nitrite (NO2) + Nitrate (NO3) as N
# 2224              pH                                            pH
# 2225          TP_ugl                               Phosphorus as P
# 2226          OP_mgl              Phosphorus, phosphate (PO4) as P
# ...

# %%
print("Parameters from 12-09-1980 0:00")
data.loc[data['SampleDate'] == "12-09-1980 0:00", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 12-09-1980 0:00
#            Parameter                    Characteristic Sample_Fraction  \
# 2230     Cl_diss_mgl                          Chloride       Dissolved
# 2231          DO_mgl             Dissolved oxygen (DO)           Total
# 2232           F_mgl                         Fluorides           Total
# 2233          Fe_ugl                              Iron           Total
# 2234         TKN_ugl                Nitrogen, Kjeldahl           Total
# 2235          TP_ugl                   Phosphorus as P           Total
# 2236          OP_mgl  Phosphorus, phosphate (PO4) as P           Total
# 2237     Cond_umhocm              Specific conductance           Total
# 2238         TempW_C                Temperature, water           Total
# 2239  Color_true_pcu                        True Color           Total
# 2240         TempW_F                Temperature, water             NaN
#
#       Result_Value Result_Unit
# 2230        23.300        mg/l
# ...

# %%
print("Parameters from 2/14/2013 12:00:00 AM")
data.loc[data['SampleDate'] == "2/14/2013 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 2/14/2013 12:00:00 AM
#         Parameter               Characteristic Sample_Fraction  Result_Value  \
# 834       TempW_C           Temperature, water             NaN      22.64000
# 835   Cond_umhocm         Specific conductance             NaN     712.00000
# 836     Secchi_ft            Secchi disk depth             NaN       0.98424
# 837            pH                           pH             NaN       7.60000
# 838   Fe_diss_ugl                         Iron       Dissolved      92.00000
# 839    DO_percent  Dissolved oxygen saturation             NaN      99.40000
# 840        DO_mgl        Dissolved oxygen (DO)             NaN       8.57000
# 841       TempW_F           Temperature, water             NaN      72.75200
# 1088      TempW_F           Temperature, water             NaN      73.22000
# 1089      TempW_C           Temperature, water             NaN      22.90000
# 1090  Cond_umhocm         Specific conductance             NaN     654.00000
# ...

# %%
print("Parameters from 04-03-2013 0:00")
data.loc[data['SampleDate'] == "04-03-2013 0:00", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 04-03-2013 0:00
#         Parameter               Characteristic Sample_Fraction  Result_Value  \
# 842       TempW_C           Temperature, water             NaN      26.07000
# 843   Cond_umhocm         Specific conductance             NaN     582.00000
# 844     Secchi_ft            Secchi disk depth             NaN       0.98424
# 845            pH                           pH             NaN       7.52000
# 846   Fe_diss_ugl                         Iron       Dissolved     120.00000
# 847    DO_percent  Dissolved oxygen saturation             NaN     118.90000
# 848        DO_mgl        Dissolved oxygen (DO)             NaN       9.62000
# 849       TempW_F           Temperature, water             NaN      78.92600
# 1096      TempW_F           Temperature, water             NaN      78.56600
# 1097  Cond_umhocm         Specific conductance             NaN     583.00000
# 1098      TempW_C           Temperature, water             NaN      25.87000
# ...

# %%
print("Parameters from 6/26/2013 12:00:00 AM")
data.loc[data['SampleDate'] == "6/26/2013 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 6/26/2013 12:00:00 AM
#         Parameter               Characteristic Sample_Fraction  Result_Value  \
# 850       TempW_C           Temperature, water             NaN      30.16000
# 851   Cond_umhocm         Specific conductance             NaN     447.00000
# 852     Secchi_ft            Secchi disk depth             NaN       1.64040
# 853            pH                           pH             NaN       7.53000
# 854   Fe_diss_ugl                         Iron       Dissolved     260.00000
# 855    DO_percent  Dissolved oxygen saturation             NaN     177.50000
# 856        DO_mgl        Dissolved oxygen (DO)             NaN      13.36000
# 857       TempW_F           Temperature, water             NaN      86.28800
# 1104       DO_mgl        Dissolved oxygen (DO)             NaN      12.27000
# 1105   DO_percent  Dissolved oxygen saturation             NaN     163.50000
# 1106  Fe_diss_ugl                         Iron       Dissolved     150.00000
# ...

# %%
print("Parameters from 8/20/2013 12:00:00 AM")
data.loc[data['SampleDate'] == "8/20/2013 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 8/20/2013 12:00:00 AM
#           Parameter               Characteristic  Sample_Fraction  \
# 858         TempW_C           Temperature, water              NaN
# 859     Cond_umhocm         Specific conductance              NaN
# 860       Secchi_ft            Secchi disk depth              NaN
# 861              pH                           pH              NaN
# 862          Fe_ugl                         Iron  Total Recovrble
# 863      DO_percent  Dissolved oxygen saturation              NaN
# 864          DO_mgl        Dissolved oxygen (DO)              NaN
# 865   Depth_bott_ft                Depth, bottom              NaN
# 866         TempW_F           Temperature, water              NaN
# 1112        TempW_F           Temperature, water              NaN
# 1113  Depth_bott_ft                Depth, bottom              NaN
# 1114         DO_mgl        Dissolved oxygen (DO)              NaN
# 1115     DO_percent  Dissolved oxygen saturation              NaN
# ...

# %%
print("Parameters from 9/19/2013 12:00:00 AM")
data.loc[data['SampleDate'] == "9/19/2013 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# Out:
# Parameters from 9/19/2013 12:00:00 AM
#           Parameter               Characteristic  Sample_Fraction  \
# 1121  Depth_bott_ft                Depth, bottom              NaN
# 1122         DO_mgl        Dissolved oxygen (DO)              NaN
# 1123     DO_percent  Dissolved oxygen saturation              NaN
# 1124         Fe_ugl                         Iron  Total Recovrble
# 1125             pH                           pH              NaN
# 1126      Secchi_ft            Secchi disk depth              NaN
# 1127    Cond_umhocm         Specific conductance              NaN
# 1128        TempW_C           Temperature, water              NaN
# 1129        TempW_F           Temperature, water              NaN
# 2271        TempW_F           Temperature, water              NaN
# 2272  Depth_bott_ft                Depth, bottom              NaN
# 2273         DO_mgl        Dissolved oxygen (DO)              NaN
# 2274     DO_percent  Dissolved oxygen saturation              NaN
# ...

# %%
print("Parameters from 10/16/2013 12:00:00 AM")
data.loc[data['SampleDate'] == "10/16/2013 12:00:00 AM", ['Parameter', 'Characteristic', 'Sample_Fraction', 'Result_Value', 'Result_Unit']]
# data.loc[data['SampleDate'] == "10/16/2013 12:00:00 AM", 'Characteristic']
# Out:
# Parameters from 10/16/2013 12:00:00 AM
#           Parameter               Characteristic  Sample_Fraction  \
# 1130        TempW_F           Temperature, water              NaN
# 1131  Depth_bott_ft                Depth, bottom              NaN
# 1132         DO_mgl        Dissolved oxygen (DO)              NaN
# 1133     DO_percent  Dissolved oxygen saturation              NaN
# 1134         Fe_ugl                         Iron  Total Recovrble
# 1135             pH                           pH              NaN
# 1136      Secchi_ft            Secchi disk depth              NaN
# 1137    Cond_umhocm         Specific conductance              NaN
# 1138        TempW_C           Temperature, water              NaN
# 2280  Depth_bott_ft                Depth, bottom              NaN
# 2281         DO_mgl        Dissolved oxygen (DO)              NaN
# 2282     DO_percent  Dissolved oxygen saturation              NaN
# 2283         Fe_ugl                         Iron  Total Recovrble
# ...

# %%
fig = plt.figure(figsize=(250,30))
plt.scatter(data['SampleDate'], data['Parameter'])
plt.xlabel('Time')
plt.ylabel('Parameter')
# Out:
# Text(0, 0.5, 'Parameter')

# %%
fig = plt.figure(figsize=(250,30))
plt.scatter(data['SampleDate'], data['Characteristic'])
plt.xlabel('Time')
plt.ylabel('Characteristic')
# Out:
# Text(0, 0.5, 'Characteristic')

# %%
# fig = plt.figure(figsize=(250,30))
# plt.scatter(data['SampleDate'], data['Sample_Fraction'])
# plt.xlabel('Time')
# plt.ylabel('Sample Fraction')

# %%
fig = plt.figure(figsize=(300,100))
plt.scatter(data['SampleDate'], data['Result_Value'])
plt.xlabel('Time')
plt.ylabel('Result_Value')
# Out:
# Text(0, 0.5, 'Result_Value')

# %%
fig = plt.figure(figsize=(250,30))
plt.scatter(data['SampleDate'], data['Result_Unit'])
plt.xlabel('Time')
plt.ylabel('Result Unit')
# Out:
# Text(0, 0.5, 'Result Unit')

# %%
data.corr()
# Out:
#                        WBodyID  WaterBodyName  Actual_Latitude  \
# WBodyID                    NaN            NaN              NaN
# WaterBodyName              NaN            NaN              NaN
# Actual_Latitude            NaN            NaN         1.000000
# Actual_Longitude           NaN            NaN        -0.950802
# ActivityDepth              NaN            NaN         0.874456
# Characteristic             NaN            NaN         0.148114
# Result_Value               NaN            NaN         0.099274
# Original_Result_Value      NaN            NaN        -0.006243
#
#                        Actual_Longitude  ActivityDepth  Characteristic  \
# WBodyID                             NaN            NaN             NaN
# WaterBodyName                       NaN            NaN             NaN
# Actual_Latitude               -0.950802       0.874456        0.148114
# Actual_Longitude               1.000000      -0.796486       -0.119639
# ...

# %%
print("ActivityDepth and Actual_Latitude = .874456")
print("ActivityDepth and Actual_Longitude = -.796486")
print("Actual_Latitude and Actual_Longitude = -.950802")
# Out:
# ActivityDepth and Actual_Latitude = .874456
# ActivityDepth and Actual_Longitude = -.796486
# Actual_Latitude and Actual_Longitude = -.950802

# %%
import seaborn as sns
sns.heatmap(data.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
print("The heatmap indicates that there is a strong correlation between Actual_Latitude, Actual_Longitude, and ActivityDepth")
# Out:
# The heatmap indicates that there is a strong correlation between Actual_Latitude, Actual_Longitude, and ActivityDepth
